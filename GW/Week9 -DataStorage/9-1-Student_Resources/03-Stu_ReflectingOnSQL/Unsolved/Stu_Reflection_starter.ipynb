# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import inspect, create_engine, MetaData, Table
import pandas as pd

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///../Resources/demographics.sqlite")

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect = True)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['demographics']

# %%
# Assign the demographics class to a variable called `Demographics`
Demographics = Base.classes.demographics

# %%
# Create a session
session = Session(engine)

# %%
# Use the session to query Demographics table and display the first 5 locations
# inspector = inspect(engine)
# for column in inspector.get_columns("Demographics") :
#     print(column["name"])
for row in session.query(Demographics.location).limit(5).all():
    print(row)
# Out:
# ('South Dakota',)
# ('Delaware',)
# ('South Dakota',)
# ('Louisiana',)
# ('West Virginia',)

# %%
# BONUS: Query and print the number of unique Locations
# Hints: Look into counting and grouping operations in SQLAlchemy
conn = engine.connect()
data = pd.read_sql("SELECT location, COUNT(location) FROM Demographics GROUP BY location", conn)
data
# data["location"].value_counts()
# Out:
#         location  COUNT(location)
# 0         Alaska              191
# 1       Delaware              188
# 2      Louisiana              204
# 3   South Dakota              214
# 4  West Virginia              203

# %%
inspector = inspect(engine)

# %%
columns = inspector.get_columns("Demographics")
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# age INTEGER
# height_meter FLOAT
# weight_kg FLOAT
# children INTEGER
# occupation TEXT
# academic_degree TEXT
# salary INTEGER
# location TEXT

# %%
metadata = MetaData() ##same as inspect, describe tables

# %%
table = Table("Demographics", metadata, autoload = True, autoload_with = engine)

# %%
table.columns.keys()
# Out:
# ['id',
#  'age',
#  'height_meter',
#  'weight_kg',
#  'children',
#  'occupation',
#  'academic_degree',
#  'salary',
#  'location']

# %%
table.primary_key
# Out:
# PrimaryKeyConstraint(Column('id', INTEGER(), table=<Demographics>, primary_key=True, nullable=False))

# %%
data = engine.execute("SELECT * FROM Demographics")
data.fetchall()
# Out:
# [(0, 58, 1.87, 53.0, 1, 'Choreographer', 'PhD', 68, 'South Dakota'),
#  (1, 65, 1.8, 40.0, 0, 'Cellarman', 'Bachelor', 73, 'Delaware'),
#  (2, 32, 1.8, 73.0, 1, 'Veterinary Surgeon', 'Master', 69, 'South Dakota'),
#  (3, 61, 1.79, 89.0, 0, 'Hawker', 'PhD', 88, 'Louisiana'),
#  (4, 23, 1.64, 51.0, 2, 'Choreographer', 'Bachelor', 83, 'West Virginia'),
#  (5, 20, 1.68, 60.0, 4, 'Medical Physicist', 'Bachelor', 65, 'South Dakota'),
#  (6, 31, 1.56, 62.0, 0, 'Weaver', 'Master', 72, 'Louisiana'),
#  (7, 56, 1.6, 42.0, 0, 'Lighthouse Keeper', 'Master', 65, 'Louisiana'),
#  (8, 30, 1.62, 44.0, 3, 'Millwright', 'Master', 87, 'Louisiana'),
#  (9, 44, 1.69, 51.0, 5, 'Medical Supplier', 'PhD', 72, 'West Virginia'),
#  (10, 55, 1.82, 72.0, 5, 'Manicurist', 'Bachelor', 73, 'South Dakota'),
#  (11, 66, 1.63, 78.0, 5, 'Window Dresser', 'Bachelor', 90, 'Delaware'),
#  (12, 62, 1.88, 41.0, 1, 'Assistant', 'Master', 78, 'Alaska'),
#  (13, 35, 1.53, 74.0, 5, 'Paramedic', 'Bachelor', 69, 'Delaware'),
#  (14, 66, 1.94, 79.0, 3, 'Genealogist', 'Master', 75, 'South Dakota'),
#  (15, 23, 1.87, 72.0, 2, 'Servant', 'PhD', 77, 'South Dakota'),
#  (16, 40, 1.61, 46.0, 4, 'Technical Liaison', 'Bachelor', 76, 'Louisiana'),
#  (17, 34, 1.55, 78.0, 1, 'Scientist', 'PhD', 90, 'South Dakota'),
#  (18, 64, 1.69, 67.0, 4, 'Market Research', 'PhD', 79, 'Louisiana'),
#  (19, 25, 1.86, 81.0, 4, 'Medical Supplier', 'PhD', 77, 'South Dakota'),
#  (20, 53, 1.65, 48.0, 3, 'Actor', 'PhD', 74, 'Louisiana'),
#  (21, 41, 1.75, 49.0, 4, 'Claims Adjustor', 'PhD', 83, 'Delaware'),
#  (22, 63, 1.82, 76.0, 1, 'Groom', 'Master', 67, 'South Dakota'),
#  (23, 60, 1.98, 71.0, 0, 'Payroll Assistant', 'Master', 72, 'Alaska'),
#  (24, 23, 1.96, 89.0, 2, 'Machine Operator', 'Bachelor', 72, 'South Dakota'),
#  (25, 42, 1.78, 43.0, 0, 'Tea Blender', 'Bachelor', 73, 'West Virginia'),
#  (26, 58, 1.56, 80.0, 3, 'Warden', 'Bachelor', 76, 'Delaware'),
#  (27, 41, 1.94, 65.0, 1, 'Undertaker', 'PhD', 76, 'Delaware'),
#  (28, 60, 1.66, 80.0, 5, 'Psychiatrist', 'Master', 73, 'South Dakota'),
#  (29, 56, 1.56, 52.0, 0, 'Planning Technician', 'Bachelor', 85, 'Delaware'),
#  (30, 52, 1.79, 38.0, 0, 'Booking Clerk', 'Bachelor', 88, 'Delaware'),
#  (31, 28, 1.52, 59.0, 0, 'Track Worker', 'Bachelor', 79, 'West Virginia'),
#  (32, 35, 1.74, 72.0, 1, 'Sub-Postmaster', 'Bachelor', 85, 'Louisiana'),
#  (33, 32, 1.7, 44.0, 0, 'Shelf Filler', 'Master', 86, 'Alaska'),
#  (34, 67, 1.73, 84.0, 0, 'Chemist', 'Bachelor', 89, 'South Dakota'),
#  (35, 32, 1.67, 44.0, 1, 'Injection Moulder', 'Bachelor', 66, 'Alaska'),
#  (36, 43, 1.57, 49.0, 2, 'Stenographer', 'Bachelor', 73, 'South Dakota'),
#  (37, 31, 1.9, 73.0, 0, 'Betting Shop', 'PhD', 83, 'Alaska'),
#  (38, 31, 1.51, 43.0, 1, 'Hire Car Driver', 'Master', 85, 'West Virginia'),
#  (39, 43, 1.61, 63.0, 0, 'Heating Engineer', 'Master', 85, 'West Virginia'),
#  (40, 27, 1.63, 88.0, 3, 'Motor Mechanic', 'Master', 73, 'Delaware'),
#  (41, 33, 1.59, 51.0, 0, 'Vehicle Assessor', 'Bachelor', 88, 'Louisiana'),
#  (42, 52, 1.53, 68.0, 4, 'Tree Surgeon', 'Bachelor', 73, 'Louisiana'),
#  (43, 45, 1.75, 49.0, 0, 'Building Surveyor', 'PhD', 83, 'West Virginia'),
#  (44, 41, 1.56, 74.0, 1, 'Auto Electrician', 'PhD', 72, 'Delaware'),
#  (45, 50, 1.83, 74.0, 4, 'Park Ranger', 'Master', 80, 'South Dakota'),
#  (46, 66, 1.86, 53.0, 2, 'Relocation Agent', 'Bachelor', 66, 'South Dakota'),
#  (47, 27, 1.66, 86.0, 0, 'Advertising Contractor', 'Master', 85, 'Delaware'),
#  (48, 61, 1.77, 70.0, 2, 'Furnace Man', 'Master', 78, 'Louisiana'),
#  (49, 22, 1.62, 56.0, 1, 'Shooting Instructor', 'PhD', 77, 'West Virginia'),
#  (50, 56, 1.99, 89.0, 5, 'Travel Representative', 'Bachelor', 79, 'Louisiana'),
#  (51, 34, 1.97, 44.0, 1, 'Medical Physicist', 'Bachelor', 82, 'South Dakota'),
#  (52, 61, 1.78, 55.0, 2, 'Labourer', 'PhD', 88, 'South Dakota'),
#  (53, 61, 1.84, 54.0, 4, 'Technical Analyst', 'Master', 82, 'Alaska'),
#  (54, 67, 1.82, 55.0, 0, 'Actress', 'Master', 85, 'Alaska'),
#  (55, 25, 1.99, 48.0, 5, 'Show Jumper', 'PhD', 74, 'West Virginia'),
#  (56, 28, 1.5, 42.0, 5, 'Granite Technician', 'PhD', 79, 'South Dakota'),
#  (57, 64, 1.68, 73.0, 1, 'Share Dealer', 'Bachelor', 88, 'Alaska'),
#  (58, 50, 1.68, 88.0, 0, 'Prison Officer', 'Bachelor', 89, 'Delaware'),
#  (59, 50, 1.55, 87.0, 4, 'Riding Instructor', 'PhD', 68, 'Alaska'),
#  (60, 58, 1.96, 48.0, 1, 'Rug Maker', 'Bachelor', 81, 'Louisiana'),
#  (61, 30, 1.96, 88.0, 3, 'Marine Electrician', 'Master', 69, 'Alaska'),
#  (62, 66, 1.85, 62.0, 0, 'Stud Hand', 'Bachelor', 70, 'Louisiana'),
#  (63, 67, 1.96, 60.0, 2, 'Lighthouse Keeper', 'Bachelor', 81, 'South Dakota'),
#  (64, 56, 1.6, 59.0, 2, 'Bus Conductor', 'Master', 75, 'West Virginia'),
#  (65, 19, 1.75, 81.0, 4, 'Piano Tuner', 'Bachelor', 68, 'Alaska'),
#  (66, 37, 1.99, 49.0, 4, 'Medical Researcher', 'Bachelor', 72, 'South Dakota'),
#  (67, 33, 1.72, 84.0, 2, 'Shipwright', 'PhD', 83, 'South Dakota'),
#  (68, 23, 1.69, 74.0, 1, 'Marketing Manager', 'Bachelor', 88, 'West Virginia'),
#  (69, 22, 1.76, 89.0, 4, 'Insurance Inspector', 'Master', 89, 'Louisiana'),
#  (70, 67, 1.97, 59.0, 4, 'Pallet Maker', 'PhD', 69, 'Delaware'),
#  (71, 60, 1.95, 70.0, 2, 'Road Safety Officer', 'Master', 80, 'Louisiana'),
#  (72, 28, 1.65, 46.0, 1, 'School Crossing', 'PhD', 73, 'Louisiana'),
#  (73, 56, 1.87, 49.0, 4, 'Opera Singer', 'Master', 78, 'Delaware'),
#  (74, 52, 1.5, 56.0, 1, 'Share Dealer', 'PhD', 89, 'Delaware'),
#  (75, 63, 1.72, 81.0, 1, 'Tour Agent', 'Master', 74, 'West Virginia'),
#  (76, 60, 1.54, 70.0, 5, 'Pipe Inspector', 'Bachelor', 85, 'Alaska'),
#  (77, 46, 1.66, 89.0, 1, 'Golf Club Professional', 'Bachelor', 81, 'West Virginia'),
#  (78, 25, 1.99, 77.0, 0, 'Sportsperson', 'Master', 72, 'Delaware'),
#  (79, 22, 1.85, 69.0, 3, 'Maintenance Fitter', 'Bachelor', 75, 'South Dakota'),
#  (80, 55, 1.88, 87.0, 0, 'Seaman', 'Bachelor', 82, 'Delaware'),
#  (81, 55, 1.98, 71.0, 3, 'Beauty Therapist', 'PhD', 72, 'South Dakota'),
#  (82, 22, 1.92, 67.0, 1, 'Stock Manager', 'PhD', 87, 'South Dakota'),
#  (83, 32, 1.8, 86.0, 3, 'Theatre Technician', 'Master', 67, 'South Dakota'),
#  (84, 39, 1.95, 85.0, 3, 'Song Writer', 'Master', 67, 'Louisiana'),
#  (85, 33, 1.82, 87.0, 4, 'Taxi Controller', 'PhD', 73, 'West Virginia'),
#  (86, 31, 1.72, 83.0, 2, 'Lock Keeper', 'Master', 82, 'Delaware'),
#  (87, 64, 1.95, 43.0, 1, 'Grave Digger', 'Bachelor', 83, 'Louisiana'),
#  (88, 48, 1.58, 51.0, 0, 'Sales Assistant', 'Master', 72, 'West Virginia'),
#  (89, 44, 1.73, 41.0, 1, 'Scaffolder', 'Master', 71, 'South Dakota'),
#  (90, 24, 1.94, 74.0, 3, 'Systems Manager', 'Bachelor', 86, 'West Virginia'),
#  (91, 40, 1.88, 64.0, 4, 'Video Artist', 'PhD', 78, 'West Virginia'),
#  (92, 47, 1.61, 65.0, 3, 'Art Restorer', 'Master', 88, 'South Dakota'),
#  (93, 61, 1.84, 63.0, 5, 'Herbalist', 'Master', 85, 'South Dakota'),
#  (94, 21, 1.77, 63.0, 4, 'Zoologist', 'PhD', 77, 'Alaska'),
#  (95, 24, 1.82, 46.0, 3, 'Housekeeper', 'Bachelor', 72, 'Delaware'),
#  (96, 30, 1.66, 67.0, 2, 'Planning Officer', 'Master', 82, 'West Virginia'),
#  (97, 26, 1.98, 64.0, 2, 'Car Valet', 'Master', 78, 'Delaware'),
#  (98, 35, 1.77, 60.0, 1, 'Bursar', 'PhD', 79, 'Delaware'),
#  (99, 22, 1.52, 53.0, 1, 'Analyst', 'PhD', 79, 'Louisiana'),
#  (100, 24, 1.56, 80.0, 0, 'Zoologist', 'Bachelor', 66, 'Louisiana'),
#  (101, 18, 1.63, 61.0, 1, 'Doctor', 'Bachelor', 67, 'Delaware'),
#  (102, 28, 1.79, 57.0, 4, 'Public House Manager', 'Master', 78, 'West Virginia'),
#  (103, 48, 1.8, 78.0, 1, 'Chiropractor', 'PhD', 71, 'West Virginia'),
#  (104, 21, 1.84, 89.0, 0, 'Baggage Handler', 'Master', 70, 'West Virginia'),
#  (105, 18, 1.83, 42.0, 4, 'Plant Operator', 'Bachelor', 77, 'Alaska'),
#  (106, 47, 1.75, 65.0, 2, 'Station Manager', 'PhD', 74, 'West Virginia'),
#  (107, 62, 1.59, 71.0, 5, 'Metal Dealer', 'PhD', 88, 'Louisiana'),
#  (108, 60, 1.74, 65.0, 5, 'Merchant', 'Master', 87, 'West Virginia'),
#  (109, 27, 1.97, 55.0, 3, 'Maintenance Fitter', 'Master', 71, 'Alaska'),
#  (110, 31, 1.51, 58.0, 1, 'Teachers Assistant', 'Bachelor', 66, 'Louisiana'),
#  (111, 65, 1.63, 55.0, 4, 'Mill Operator', 'PhD', 82, 'South Dakota'),
#  (112, 65, 1.97, 43.0, 1, 'Riding Instructor', 'Master', 75, 'South Dakota'),
#  (113, 21, 1.62, 68.0, 5, 'Technical Director', 'Master', 83, 'West Virginia'),
#  (114, 50, 1.65, 63.0, 5, 'Maid', 'Master', 81, 'Delaware'),
#  (115, 21, 1.78, 60.0, 3, 'Warehouseman', 'Master', 81, 'South Dakota'),
#  (116, 29, 1.73, 57.0, 2, 'Lineman', 'Bachelor', 67, 'Louisiana'),
#  (117, 22, 1.56, 72.0, 5, 'Hypnotist', 'Bachelor', 86, 'Delaware'),
#  (118, 43, 1.74, 84.0, 4, 'Transport Manager', 'PhD', 68, 'Louisiana'),
#  (119, 33, 1.92, 56.0, 1, 'Product Installer', 'Bachelor', 83, 'Louisiana'),
#  (120, 20, 1.85, 46.0, 2, 'Bank Messenger', 'Bachelor', 84, 'South Dakota'),
#  (121, 44, 1.85, 46.0, 5, 'Technical Director', 'Bachelor', 86, 'Louisiana'),
#  (122, 54, 1.64, 68.0, 3, 'Plant Manager', 'Bachelor', 81, 'Alaska'),
#  (123, 34, 1.97, 68.0, 0, 'Building Control', 'Master', 71, 'Alaska'),
#  (124, 33, 1.79, 81.0, 0, 'Green Keeper', 'Bachelor', 73, 'West Virginia'),
#  (125, 26, 2.0, 45.0, 4, 'Sales Executive', 'PhD', 86, 'Alaska'),
#  (126, 47, 1.76, 66.0, 3, 'Nursing Sister', 'PhD', 75, 'South Dakota'),
#  (127, 18, 1.78, 41.0, 4, 'Child Minder', 'Bachelor', 79, 'Louisiana'),
#  (128, 54, 1.83, 48.0, 1, 'Horticultural Consultant', 'PhD', 68, 'South Dakota'),
#  (129, 52, 1.5, 66.0, 5, 'Street Trader', 'Master', 71, 'Louisiana'),
#  (130, 34, 1.64, 56.0, 5, 'Sports Coach', 'Bachelor', 69, 'Alaska'),
#  (131, 22, 1.63, 88.0, 5, 'Interior Decorator', 'Master', 72, 'Alaska'),
#  (132, 36, 1.61, 47.0, 2, 'Gate Keeper', 'Bachelor', 70, 'West Virginia'),
#  (133, 52, 1.9, 76.0, 5, 'Nanny', 'Master', 87, 'Alaska'),
#  (134, 57, 1.84, 82.0, 3, 'Metallurgist', 'PhD', 90, 'Louisiana'),
#  (135, 18, 1.72, 76.0, 0, 'Shepherd', 'PhD', 86, 'Louisiana'),
#  (136, 37, 1.63, 43.0, 1, 'Analytical Chemist', 'PhD', 86, 'South Dakota'),
#  (137, 26, 1.52, 86.0, 1, 'Stud Hand', 'PhD', 73, 'South Dakota'),
#  (138, 24, 1.64, 75.0, 3, 'Technical Engineer', 'Bachelor', 88, 'Louisiana'),
#  (139, 27, 1.7, 58.0, 5, 'Circus Worker', 'Bachelor', 73, 'Alaska'),
#  (140, 56, 1.85, 56.0, 5, 'Research Consultant', 'PhD', 71, 'Alaska'),
#  (141, 31, 1.54, 54.0, 2, 'Editor', 'Master', 86, 'Alaska'),
#  (142, 50, 1.99, 80.0, 4, 'Steeplejack', 'Master', 80, 'Alaska'),
#  (143, 21, 1.76, 77.0, 3, 'Showman', 'Bachelor', 67, 'West Virginia'),
#  (144, 35, 1.77, 56.0, 3, 'Taxi Controller', 'Bachelor', 66, 'South Dakota'),
#  (145, 39, 1.82, 89.0, 1, 'Hardware Dealer', 'Master', 89, 'Delaware'),
#  (146, 58, 1.78, 43.0, 1, 'Decorator', 'Master', 73, 'Delaware'),
#  (147, 65, 1.92, 69.0, 5, 'Night Watchman', 'PhD', 79, 'Louisiana'),
#  (148, 63, 1.92, 68.0, 1, 'Stable Hand', 'PhD', 78, 'Louisiana'),
#  (149, 18, 1.6, 76.0, 4, 'Gaming Board Inspector', 'Bachelor', 68, 'South Dakota'),
#  (150, 62, 1.9, 64.0, 2, 'Ticket Inspector', 'Master', 69, 'Louisiana'),
#  (151, 20, 1.86, 75.0, 4, 'Technical Author', 'Bachelor', 76, 'Louisiana'),
#  (152, 53, 1.74, 59.0, 4, 'Vehicle Engineer', 'Master', 69, 'West Virginia'),
#  (153, 26, 1.66, 50.0, 5, 'Machine Minder', 'PhD', 66, 'Alaska'),
#  (154, 41, 1.93, 64.0, 0, 'Parts Supervisor', 'PhD', 90, 'South Dakota'),
#  (155, 40, 1.96, 62.0, 3, 'Greengrocer', 'Master', 71, 'Delaware'),
#  (156, 60, 1.75, 75.0, 2, 'Chimney Sweep', 'Master', 68, 'Alaska'),
#  (157, 67, 1.96, 38.0, 5, 'Geophysicist', 'Master', 82, 'West Virginia'),
#  (158, 57, 1.73, 54.0, 2, 'Repair Man', 'PhD', 88, 'Delaware'),
#  (159, 33, 1.66, 81.0, 4, 'Purser', 'Master', 70, 'Delaware'),
#  (160, 44, 1.77, 77.0, 0, 'Lock Keeper', 'PhD', 65, 'Delaware'),
#  (161, 65, 1.87, 65.0, 0, 'Chimney Sweep', 'Master', 75, 'West Virginia'),
#  (162, 60, 1.65, 39.0, 0, 'Payroll Clerk', 'Bachelor', 88, 'Delaware'),
#  (163, 35, 1.69, 47.0, 1, 'Tree Surgeon', 'Master', 70, 'South Dakota'),
#  (164, 42, 1.59, 77.0, 3, 'Machine Tool Fitter', 'Master', 66, 'West Virginia'),
#  (165, 32, 1.73, 54.0, 3, 'Marquee Erector', 'PhD', 71, 'West Virginia'),
#  (166, 40, 1.9, 56.0, 5, 'Violin Maker', 'Bachelor', 74, 'Delaware'),
#  (167, 32, 1.97, 75.0, 2, 'Script Writer', 'PhD', 65, 'Delaware'),
#  (168, 43, 1.92, 50.0, 3, 'Tax Inspector', 'Bachelor', 75, 'Alaska'),
#  (169, 22, 1.79, 74.0, 2, 'Nurseryman', 'Bachelor', 89, 'Alaska'),
#  (170, 40, 1.5, 81.0, 5, 'Barrister', 'PhD', 85, 'Louisiana'),
#  (171, 43, 1.95, 56.0, 1, 'Precision Engineer', 'Bachelor', 86, 'Louisiana'),
#  (172, 39, 1.63, 86.0, 5, 'Gaming Club Manager', 'PhD', 65, 'South Dakota'),
#  (173, 34, 1.81, 40.0, 2, 'Shop Proprietor', 'Bachelor', 70, 'Louisiana'),
#  (174, 34, 1.57, 56.0, 2, 'Sales Director', 'Bachelor', 66, 'South Dakota'),
#  (175, 56, 1.89, 61.0, 4, 'Textile Consultant', 'Master', 78, 'Alaska'),
#  (176, 64, 1.96, 68.0, 2, 'Plant Attendant', 'Bachelor', 90, 'Alaska'),
#  (177, 45, 1.54, 86.0, 1, 'Rent Offcer', 'PhD', 84, 'Louisiana'),
#  (178, 25, 1.9, 38.0, 2, 'Typewriter Engineer', 'Bachelor', 77, 'Louisiana'),
#  (179, 30, 1.84, 81.0, 2, 'Quality Engineer', 'PhD', 73, 'South Dakota'),
#  (180, 63, 1.84, 68.0, 0, 'Yacht Master', 'Master', 78, 'South Dakota'),
#  (181, 51, 1.53, 90.0, 3, 'Operative', 'PhD', 90, 'Louisiana'),
#  (182, 61, 1.57, 40.0, 2, 'Technical Illustrator', 'Bachelor', 88, 'Delaware'),
#  (183, 41, 1.94, 46.0, 3, 'Sports Coach', 'Master', 78, 'South Dakota'),
#  (184, 60, 1.79, 84.0, 1, 'Sales Assistant', 'PhD', 75, 'Louisiana'),
#  (185, 38, 1.74, 64.0, 2, 'Assistant Cook', 'PhD', 86, 'South Dakota'),
#  (186, 64, 1.72, 53.0, 2, 'Child Minder', 'PhD', 74, 'Louisiana'),
#  (187, 37, 1.95, 79.0, 2, 'Breeder', 'Master', 86, 'West Virginia'),
#  (188, 38, 1.98, 90.0, 3, 'Catering Staff', 'PhD', 77, 'Alaska'),
#  (189, 53, 1.82, 39.0, 0, 'Pig Manager', 'Bachelor', 69, 'Delaware'),
#  (190, 44, 1.78, 42.0, 4, 'Judge', 'PhD', 86, 'West Virginia'),
#  (191, 61, 1.93, 59.0, 1, 'Acoustic Engineer', 'Master', 88, 'Delaware'),
#  (192, 57, 1.77, 89.0, 1, 'Clerk', 'PhD', 83, 'Alaska'),
#  (193, 43, 1.51, 88.0, 1, 'Payroll Assistant', 'Bachelor', 82, 'South Dakota'),
#  (194, 37, 1.53, 85.0, 3, 'Travel Agent', 'Bachelor', 74, 'Delaware'),
#  (195, 45, 1.72, 61.0, 4, 'Clergyman', 'Master', 90, 'Louisiana'),
#  (196, 56, 1.97, 40.0, 5, 'Training Officer', 'Master', 85, 'Alaska'),
#  (197, 47, 1.98, 41.0, 3, 'Research Scientist', 'Master', 79, 'West Virginia'),
#  (198, 61, 1.86, 66.0, 0, 'Car Park Attendant', 'Master', 71, 'Louisiana'),
#  (199, 48, 1.56, 77.0, 5, 'Waiter', 'PhD', 90, 'Delaware'),
#  (200, 60, 2.0, 71.0, 2, 'Sports Coach', 'PhD', 67, 'Alaska'),
#  (201, 50, 1.9, 45.0, 5, 'Watchmaker', 'PhD', 86, 'Louisiana'),
#  (202, 39, 1.73, 52.0, 3, 'Plant Driver', 'Master', 67, 'Delaware'),
#  (203, 61, 1.86, 58.0, 3, 'Palaeobotanist', 'PhD', 74, 'Delaware'),
#  (204, 30, 1.98, 81.0, 3, 'Building Inspector', 'Bachelor', 69, 'South Dakota'),
#  (205, 20, 1.72, 85.0, 5, 'Proprietor', 'Bachelor', 72, 'West Virginia'),
#  (206, 57, 1.98, 73.0, 2, 'Flour Miller', 'Master', 89, 'South Dakota'),
#  (207, 47, 1.83, 86.0, 3, 'Bingo Caller', 'Master', 78, 'Louisiana'),
#  (208, 30, 1.55, 70.0, 1, 'Guest House Owner', 'PhD', 87, 'West Virginia'),
#  (209, 49, 1.92, 60.0, 4, 'Project Leader', 'Bachelor', 77, 'Delaware'),
#  (210, 27, 1.61, 65.0, 4, 'Window Dresser', 'Bachelor', 85, 'South Dakota'),
#  (211, 66, 1.59, 82.0, 2, 'Plant Engineer', 'Master', 89, 'South Dakota'),
#  (212, 67, 1.93, 74.0, 5, 'Research Consultant', 'Bachelor', 78, 'Delaware'),
#  (213, 29, 1.82, 39.0, 0, 'Tree Feller', 'Bachelor', 90, 'Louisiana'),
#  (214, 47, 1.73, 48.0, 2, 'Paint Consultant', 'PhD', 66, 'Louisiana'),
#  (215, 33, 1.97, 76.0, 0, 'Biologist', 'Bachelor', 68, 'West Virginia'),
#  (216, 26, 1.81, 81.0, 0, 'Metallurgist', 'Master', 90, 'West Virginia'),
#  (217, 60, 1.8, 64.0, 2, 'Laundry Staff', 'PhD', 81, 'Louisiana'),
#  (218, 56, 1.71, 56.0, 5, 'Tea Taster', 'PhD', 75, 'West Virginia'),
#  (219, 57, 1.61, 76.0, 0, 'Administrator', 'Bachelor', 88, 'Louisiana'),
#  (220, 45, 1.61, 46.0, 2, 'Navigator', 'Master', 82, 'West Virginia'),
#  (221, 28, 1.75, 65.0, 1, 'Fraud Investigator', 'Master', 88, 'West Virginia'),
#  (222, 46, 1.62, 73.0, 5, 'Press Operator', 'Bachelor', 73, 'Delaware'),
#  (223, 58, 1.87, 65.0, 0, 'Station Manager', 'Bachelor', 73, 'Louisiana'),
#  (224, 49, 1.71, 63.0, 5, 'Sales Support', 'Master', 85, 'Delaware'),
#  (225, 35, 1.51, 58.0, 1, 'Stationer', 'PhD', 79, 'South Dakota'),
#  (226, 63, 1.72, 44.0, 1, 'Shipping Officer', 'PhD', 74, 'Delaware'),
#  (227, 35, 1.54, 57.0, 5, 'Plant Engineer', 'Bachelor', 75, 'Alaska'),
#  (228, 52, 1.58, 70.0, 5, 'Delivery Driver', 'PhD', 67, 'Delaware'),
#  (229, 27, 1.95, 60.0, 2, 'Golfer', 'Bachelor', 72, 'West Virginia'),
#  (230, 62, 1.63, 49.0, 4, 'Groom', 'PhD', 69, 'Delaware'),
#  (231, 22, 1.98, 78.0, 3, 'Stock Controller', 'PhD', 78, 'West Virginia'),
#  (232, 39, 1.96, 74.0, 5, 'Pattern Weaver', 'PhD', 82, 'West Virginia'),
#  (233, 44, 1.72, 68.0, 3, 'Optical', 'Master', 66, 'Delaware'),
#  (234, 44, 1.75, 57.0, 3, 'Special Constable', 'Bachelor', 77, 'Louisiana'),
#  (235, 62, 1.92, 42.0, 5, 'Caterer', 'PhD', 65, 'Louisiana'),
#  (236, 42, 1.73, 73.0, 5, 'Baggage Handler', 'Master', 80, 'South Dakota'),
#  (237, 40, 1.8, 70.0, 1, 'Brewery Manager', 'Master', 74, 'West Virginia'),
#  (238, 44, 1.95, 59.0, 5, 'Careers Officer', 'PhD', 82, 'Louisiana'),
#  (239, 56, 1.62, 66.0, 3, 'Transport Engineer', 'PhD', 72, 'West Virginia'),
#  (240, 32, 1.69, 56.0, 3, 'Road Sweeper', 'Master', 73, 'West Virginia'),
#  (241, 49, 1.82, 59.0, 0, 'Physiologist', 'Bachelor', 65, 'West Virginia'),
#  (242, 39, 1.63, 80.0, 4, 'Graphologist', 'Master', 86, 'West Virginia'),
#  (243, 64, 1.83, 60.0, 2, 'Recruitment Consultant', 'Bachelor', 70, 'West Virginia'),
#  (244, 26, 1.78, 79.0, 2, 'Forwarding Agent', 'PhD', 84, 'Louisiana'),
#  (245, 19, 1.82, 65.0, 4, 'Production Engineer', 'Bachelor', 77, 'Louisiana'),
#  (246, 54, 1.59, 51.0, 2, 'Tea Blender', 'Bachelor', 86, 'South Dakota'),
#  (247, 23, 1.58, 56.0, 0, 'Ticket Inspector', 'PhD', 85, 'West Virginia'),
#  (248, 26, 1.83, 87.0, 4, 'Fund Raiser', 'PhD', 79, 'Delaware'),
#  (249, 21, 1.58, 82.0, 4, 'Highway Inspector', 'PhD', 73, 'West Virginia'),
#  (250, 38, 1.71, 81.0, 5, 'Loss Assessor', 'Master', 71, 'West Virginia'),
#  (251, 38, 1.87, 66.0, 1, 'Turf Accountant', 'Bachelor', 75, 'West Virginia'),
#  (252, 35, 1.9, 68.0, 1, 'Project Manager', 'PhD', 89, 'West Virginia'),
#  (253, 34, 1.88, 87.0, 3, 'Textile Technician', 'PhD', 67, 'West Virginia'),
#  (254, 19, 1.58, 50.0, 4, 'Garage Foreman', 'Master', 88, 'Louisiana'),
#  (255, 21, 1.74, 61.0, 4, 'Church Officer', 'PhD', 76, 'Delaware'),
#  (256, 59, 1.56, 43.0, 1, 'Meteorologist', 'Master', 67, 'South Dakota'),
#  (257, 66, 1.92, 43.0, 1, 'Sound Engineer', 'Master', 65, 'Delaware'),
#  (258, 30, 1.53, 70.0, 2, 'Locum Pharmacist', 'Master', 65, 'Louisiana'),
#  (259, 27, 1.61, 58.0, 0, 'Pipe Inspector', 'Bachelor', 72, 'Delaware'),
#  (260, 48, 1.64, 68.0, 5, 'Garage Manager', 'PhD', 86, 'South Dakota'),
#  (261, 54, 1.81, 43.0, 0, 'Masseur', 'Bachelor', 71, 'West Virginia'),
#  (262, 62, 1.97, 76.0, 4, 'Screen Printer', 'Bachelor', 73, 'Alaska'),
#  (263, 28, 1.65, 41.0, 1, 'Saw Miller', 'PhD', 84, 'Louisiana'),
#  (264, 65, 1.56, 69.0, 4, 'Typesetter', 'Bachelor', 87, 'South Dakota'),
#  (265, 67, 1.62, 47.0, 2, 'Service Manager', 'Bachelor', 70, 'Alaska'),
#  (266, 24, 1.79, 49.0, 5, 'Carpenter', 'PhD', 83, 'South Dakota'),
#  (267, 37, 1.98, 72.0, 4, 'Ticket Inspector', 'PhD', 83, 'West Virginia'),
#  (268, 43, 1.94, 40.0, 5, 'Radio Presenter', 'Master', 87, 'Delaware'),
#  (269, 22, 1.51, 88.0, 0, 'Plumber', 'Bachelor', 83, 'Delaware'),
#  (270, 24, 1.79, 86.0, 2, 'Furniture Remover', 'Bachelor', 87, 'Alaska'),
#  (271, 61, 1.67, 79.0, 1, 'Stock Manager', 'PhD', 84, 'South Dakota'),
#  (272, 54, 1.59, 46.0, 0, 'Stage Director', 'Bachelor', 90, 'South Dakota'),
#  (273, 40, 1.52, 50.0, 0, 'Park Keeper', 'Master', 82, 'West Virginia'),
#  (274, 60, 1.99, 72.0, 3, 'Marketing Assistant', 'Bachelor', 76, 'South Dakota'),
#  (275, 50, 1.68, 87.0, 0, 'Picture Editor', 'Master', 85, 'Alaska'),
#  (276, 18, 1.68, 63.0, 5, 'Shop Keeper', 'Master', 78, 'West Virginia'),
#  (277, 24, 1.59, 82.0, 3, 'Project Leader', 'PhD', 78, 'Alaska'),
#  (278, 58, 1.54, 65.0, 0, 'Sheet Metal Worker', 'PhD', 79, 'Delaware'),
#  (279, 45, 1.65, 44.0, 0, 'Philatelist', 'PhD', 70, 'Louisiana'),
#  (280, 59, 1.72, 83.0, 3, 'Historian', 'PhD', 73, 'Louisiana'),
#  (281, 52, 1.72, 84.0, 2, 'Ship Builder', 'Master', 89, 'West Virginia'),
#  (282, 47, 1.84, 63.0, 2, 'Toy Maker', 'PhD', 78, 'Louisiana'),
#  (283, 35, 1.52, 76.0, 5, 'Shooting Instructor', 'Bachelor', 75, 'Delaware'),
#  (284, 23, 1.62, 79.0, 2, 'Production Engineer', 'Master', 73, 'West Virginia'),
#  (285, 33, 1.58, 66.0, 2, 'Property Manager', 'Master', 89, 'West Virginia'),
#  (286, 54, 1.57, 61.0, 3, 'Panel Beater', 'PhD', 84, 'West Virginia'),
#  (287, 39, 1.98, 39.0, 5, 'IT Manager', 'Master', 65, 'West Virginia'),
#  (288, 38, 1.96, 45.0, 2, 'Meat Inspector', 'PhD', 70, 'West Virginia'),
#  (289, 31, 2.0, 56.0, 5, 'Technical Director', 'Bachelor', 76, 'Alaska'),
#  (290, 39, 1.93, 66.0, 1, 'Site Engineer', 'Bachelor', 73, 'Louisiana'),
#  (291, 62, 1.67, 42.0, 4, 'Vehicle Assessor', 'Master', 73, 'Louisiana'),
#  (292, 18, 1.58, 83.0, 5, 'Horticulturalist', 'Master', 81, 'Delaware'),
#  (293, 23, 1.56, 50.0, 1, 'Lorry Driver', 'Master', 72, 'West Virginia'),
#  (294, 49, 1.78, 61.0, 3, 'Watchmaker', 'Bachelor', 82, 'Delaware'),
#  (295, 62, 1.65, 83.0, 5, 'Tailor', 'PhD', 80, 'West Virginia'),
#  (296, 46, 1.7, 74.0, 0, 'Foreman', 'Master', 90, 'South Dakota'),
#  (297, 23, 1.73, 71.0, 2, 'Foster Parent', 'PhD', 74, 'Delaware'),
#  (298, 43, 1.98, 65.0, 4, 'Body Fitter', 'Bachelor', 87, 'Delaware'),
#  (299, 37, 1.65, 48.0, 2, 'Licensing', 'Master', 86, 'Louisiana'),
#  (300, 41, 1.64, 43.0, 2, 'Insurance Consultant', 'PhD', 80, 'Louisiana'),
#  (301, 51, 1.56, 57.0, 4, 'Tunneller', 'Bachelor', 76, 'West Virginia'),
#  (302, 65, 1.58, 75.0, 1, 'Horse Breeder', 'PhD', 82, 'Alaska'),
#  (303, 40, 1.96, 40.0, 0, 'Car Salesman', 'Bachelor', 87, 'West Virginia'),
#  (304, 35, 1.61, 74.0, 3, 'Arts', 'Master', 74, 'Alaska'),
#  (305, 32, 1.82, 57.0, 3, 'Manicurist', 'PhD', 68, 'Delaware'),
#  (306, 38, 1.73, 82.0, 0, 'Handyman', 'Master', 68, 'Louisiana'),
#  (307, 66, 1.73, 59.0, 4, 'Geologist', 'Master', 87, 'Delaware'),
#  (308, 30, 1.99, 60.0, 3, 'Fuel Merchant', 'Master', 71, 'West Virginia'),
#  (309, 35, 1.55, 53.0, 3, 'Flour Miller', 'Master', 88, 'Louisiana'),
#  (310, 66, 1.57, 41.0, 2, 'Racehorse Groom', 'PhD', 81, 'Louisiana'),
#  (311, 36, 1.98, 48.0, 2, 'Palaeobotanist', 'Bachelor', 68, 'Delaware'),
#  (312, 36, 2.0, 67.0, 3, 'Orthoptist', 'Master', 72, 'Alaska'),
#  (313, 29, 1.97, 70.0, 3, 'Machine Tool Fitter', 'Bachelor', 74, 'South Dakota'),
#  (314, 63, 1.53, 69.0, 4, 'Stud Hand', 'Master', 82, 'Delaware'),
#  (315, 35, 1.92, 65.0, 1, 'Medical Physicist', 'PhD', 66, 'South Dakota'),
#  (316, 53, 1.7, 40.0, 3, 'Bill Poster', 'PhD', 74, 'Delaware'),
#  (317, 58, 1.78, 42.0, 3, 'Theatre Manager', 'Master', 89, 'West Virginia'),
#  (318, 24, 1.91, 77.0, 5, 'Envoy', 'Bachelor', 65, 'Louisiana'),
#  (319, 36, 1.69, 59.0, 4, 'Progress Chaser', 'Bachelor', 80, 'West Virginia'),
#  (320, 46, 1.75, 70.0, 0, 'Bank Manager', 'Bachelor', 75, 'Delaware'),
#  (321, 21, 1.67, 68.0, 4, 'Stable Hand', 'Bachelor', 73, 'West Virginia'),
#  (322, 25, 1.66, 77.0, 2, 'Health Planner', 'Master', 67, 'West Virginia'),
#  (323, 49, 1.67, 70.0, 4, 'Technical Clerk', 'PhD', 67, 'Louisiana'),
#  (324, 58, 1.91, 61.0, 2, 'Cleric', 'Master', 86, 'South Dakota'),
#  (325, 27, 1.95, 82.0, 5, 'Armourer', 'PhD', 69, 'Louisiana'),
#  (326, 37, 1.98, 88.0, 4, 'Lighthouse Keeper', 'PhD', 67, 'Delaware'),
#  (327, 25, 1.74, 71.0, 5, 'Purser', 'Bachelor', 82, 'West Virginia'),
#  (328, 56, 1.79, 82.0, 0, 'Industrial Chemist', 'Bachelor', 84, 'Louisiana'),
#  (329, 32, 1.71, 64.0, 5, 'Jazz Composer', 'Master', 89, 'Louisiana'),
#  (330, 42, 1.81, 68.0, 5, 'Brewery Worker', 'PhD', 79, 'West Virginia'),
#  (331, 37, 1.6, 58.0, 5, 'Tacker', 'PhD', 83, 'West Virginia'),
#  (332, 37, 1.98, 67.0, 4, 'Plastics Engineer', 'PhD', 83, 'Louisiana'),
#  (333, 21, 1.89, 84.0, 5, 'Medical Physicist', 'PhD', 84, 'South Dakota'),
#  (334, 66, 1.98, 55.0, 4, 'Off Shore', 'Bachelor', 71, 'Delaware'),
#  (335, 34, 1.64, 51.0, 5, 'Technical Assistant', 'Master', 86, 'South Dakota'),
#  (336, 28, 1.78, 88.0, 5, 'Microbiologist', 'Master', 72, 'Delaware'),
#  (337, 53, 1.84, 62.0, 3, 'Plumber', 'Bachelor', 67, 'Delaware'),
#  (338, 18, 1.64, 83.0, 0, 'Polisher', 'Master', 78, 'West Virginia'),
#  (339, 62, 1.74, 50.0, 4, 'Metal Polisher', 'PhD', 84, 'West Virginia'),
#  (340, 36, 1.55, 85.0, 4, 'Machine Operator', 'Bachelor', 66, 'Delaware'),
#  (341, 36, 1.95, 52.0, 5, 'Lithographer', 'Bachelor', 87, 'Alaska'),
#  (342, 62, 1.67, 68.0, 0, 'Gaming Club Proprietor', 'Bachelor', 79, 'South Dakota'),
#  (343, 61, 1.58, 79.0, 3, 'TV Editor', 'PhD', 72, 'Alaska'),
#  (344, 58, 1.98, 58.0, 2, 'Bookmaker', 'Bachelor', 83, 'Delaware'),
#  (345, 45, 1.87, 40.0, 1, 'Sales Support', 'Bachelor', 68, 'Louisiana'),
#  (346, 32, 1.7, 69.0, 1, 'Navigator', 'Bachelor', 85, 'Delaware'),
#  (347, 35, 1.78, 44.0, 2, 'Motor Engineer', 'Master', 69, 'South Dakota'),
#  (348, 21, 1.75, 46.0, 4, 'Store Detective', 'Master', 70, 'Alaska'),
#  (349, 56, 1.56, 48.0, 5, 'Stage Manager', 'PhD', 88, 'Louisiana'),
#  (350, 36, 1.59, 85.0, 2, 'Nurseryman', 'PhD', 79, 'South Dakota'),
#  (351, 47, 1.81, 78.0, 3, 'Security Guard', 'PhD', 87, 'Alaska'),
#  (352, 62, 1.7, 44.0, 1, 'Gardener', 'Master', 77, 'Alaska'),
#  (353, 50, 1.62, 54.0, 3, 'Locum Pharmacist', 'Master', 82, 'West Virginia'),
#  (354, 46, 1.66, 75.0, 5, 'Aerial Erector', 'Master', 67, 'Louisiana'),
#  (355, 20, 1.62, 80.0, 0, 'Stockman', 'Master', 78, 'Alaska'),
#  (356, 56, 1.84, 83.0, 2, 'Engineer', 'PhD', 73, 'South Dakota'),
#  (357, 23, 1.81, 52.0, 1, 'Tacker', 'Bachelor', 72, 'Louisiana'),
#  (358, 55, 1.99, 61.0, 3, 'Waitress', 'Master', 65, 'Alaska'),
#  (359, 54, 1.83, 51.0, 1, 'Car Valet', 'PhD', 66, 'Delaware'),
#  (360, 48, 1.85, 42.0, 4, 'Councillor', 'Bachelor', 81, 'West Virginia'),
#  (361, 35, 1.75, 74.0, 4, 'Graphic Designer', 'Bachelor', 70, 'Louisiana'),
#  (362, 45, 1.76, 45.0, 5, 'Jockey', 'PhD', 85, 'West Virginia'),
#  (363, 23, 1.95, 66.0, 0, 'Sports Administrator', 'Bachelor', 80, 'Alaska'),
#  (364, 44, 1.73, 41.0, 4, 'Steeplejack', 'PhD', 75, 'Alaska'),
#  (365, 60, 1.51, 54.0, 0, 'Lawyer', 'PhD', 68, 'Delaware'),
#  (366, 39, 1.71, 82.0, 0, 'Valve Technician', 'Bachelor', 78, 'West Virginia'),
#  (367, 36, 1.74, 56.0, 3, 'Hotel Consultant', 'Bachelor', 86, 'West Virginia'),
#  (368, 66, 2.0, 62.0, 3, 'Publishing Manager', 'Master', 82, 'South Dakota'),
#  (369, 47, 1.98, 72.0, 1, 'Porter', 'Bachelor', 67, 'Alaska'),
#  (370, 34, 1.7, 46.0, 5, 'Liaison Officer', 'Bachelor', 75, 'South Dakota'),
#  (371, 67, 1.73, 84.0, 4, 'Script Writer', 'PhD', 77, 'Louisiana'),
#  (372, 18, 1.61, 67.0, 2, 'Guest House Proprietor', 'Master', 86, 'Louisiana'),
#  (373, 47, 1.94, 86.0, 0, 'Assistant', 'PhD', 78, 'South Dakota'),
#  (374, 30, 1.88, 39.0, 1, 'Joinery Consultant', 'Bachelor', 81, 'Alaska'),
#  (375, 57, 1.52, 76.0, 5, 'Barman', 'Bachelor', 89, 'West Virginia'),
#  (376, 58, 1.72, 72.0, 1, 'Bodyshop', 'Bachelor', 79, 'South Dakota'),
#  (377, 31, 1.62, 84.0, 4, 'Pasteuriser', 'PhD', 73, 'Louisiana'),
#  (378, 26, 1.65, 47.0, 5, 'Training Officer', 'Bachelor', 74, 'West Virginia'),
#  (379, 62, 1.64, 73.0, 4, 'Hosiery Worker', 'PhD', 80, 'South Dakota'),
#  (380, 19, 1.75, 60.0, 5, 'Quality Engineer', 'PhD', 85, 'Louisiana'),
#  (381, 33, 1.71, 47.0, 2, 'Publican', 'Bachelor', 87, 'Delaware'),
#  (382, 37, 1.62, 52.0, 2, 'Geophysicist', 'Master', 82, 'South Dakota'),
#  (383, 53, 1.71, 64.0, 4, 'Treasurer', 'Bachelor', 78, 'South Dakota'),
#  (384, 32, 1.63, 59.0, 5, 'Camera Repairer', 'Master', 68, 'West Virginia'),
#  (385, 25, 1.77, 50.0, 0, 'Merchant', 'Master', 85, 'Delaware'),
#  (386, 49, 1.54, 89.0, 4, 'Wood Cutter', 'Bachelor', 87, 'Alaska'),
#  (387, 50, 1.93, 59.0, 2, 'Aircraft Surface Finisher', 'Bachelor', 87, 'Alaska'),
#  (388, 44, 1.87, 85.0, 3, 'Magistrate', 'PhD', 80, 'West Virginia'),
#  (389, 33, 1.96, 73.0, 2, 'Mortgage Broker', 'Master', 79, 'Louisiana'),
#  (390, 27, 1.82, 57.0, 2, 'Procurator Fiscal', 'PhD', 77, 'Delaware'),
#  (391, 56, 1.55, 84.0, 3, 'Patent Agent', 'Bachelor', 81, 'Delaware'),
#  (392, 22, 1.71, 74.0, 1, 'Glazier', 'Bachelor', 73, 'West Virginia'),
#  (393, 39, 1.97, 75.0, 5, 'Sales Support', 'Master', 90, 'Louisiana'),
#  (394, 35, 1.66, 62.0, 4, 'Map Mounter', 'Master', 65, 'Alaska'),
#  (395, 64, 1.97, 59.0, 2, 'Technical Analyst', 'PhD', 74, 'Louisiana'),
#  (396, 55, 1.58, 88.0, 2, 'Homecare Manager', 'Bachelor', 86, 'West Virginia'),
#  (397, 27, 1.59, 72.0, 5, 'Booking Clerk', 'PhD', 79, 'Louisiana'),
#  (398, 48, 1.92, 90.0, 5, 'Barman', 'Bachelor', 76, 'Alaska'),
#  (399, 53, 1.92, 52.0, 0, 'Gravel Merchant', 'Bachelor', 89, 'Louisiana'),
#  (400, 42, 1.73, 41.0, 4, 'Tax Inspector', 'PhD', 79, 'Alaska'),
#  (401, 30, 1.5, 73.0, 3, 'Aerobic Instructor', 'Bachelor', 87, 'Delaware'),
#  (402, 54, 1.64, 56.0, 0, 'Textile Engineer', 'PhD', 77, 'Delaware'),
#  (403, 67, 1.97, 49.0, 0, 'Chartered', 'PhD', 78, 'South Dakota'),
#  (404, 38, 1.6, 71.0, 2, 'Press Operator', 'Master', 88, 'West Virginia'),
#  (405, 63, 1.69, 63.0, 3, 'Maid', 'PhD', 90, 'West Virginia'),
#  (406, 42, 1.84, 43.0, 5, 'Assessor', 'Bachelor', 86, 'Delaware'),
#  (407, 49, 1.69, 68.0, 0, 'Advertising Contractor', 'PhD', 66, 'Delaware'),
#  (408, 50, 1.75, 65.0, 5, 'Piano Tuner', 'PhD', 83, 'Alaska'),
#  (409, 24, 1.76, 40.0, 1, 'Laminator', 'PhD', 79, 'South Dakota'),
#  (410, 51, 1.52, 42.0, 5, 'Mining Consultant', 'PhD', 79, 'South Dakota'),
#  (411, 64, 1.96, 58.0, 0, 'Judge', 'PhD', 69, 'West Virginia'),
#  (412, 59, 1.91, 90.0, 3, 'Cafe Owner', 'Master', 69, 'South Dakota'),
#  (413, 48, 1.62, 62.0, 5, 'Valuer', 'Master', 90, 'Alaska'),
#  (414, 39, 1.87, 88.0, 5, 'Calibration Manager', 'PhD', 84, 'West Virginia'),
#  (415, 59, 1.55, 52.0, 0, 'Plant Manager', 'PhD', 67, 'Alaska'),
#  (416, 61, 1.89, 39.0, 5, 'Meter Reader', 'Master', 82, 'West Virginia'),
#  (417, 38, 1.68, 62.0, 3, 'IT Consultant', 'PhD', 85, 'West Virginia'),
#  (418, 52, 1.89, 56.0, 1, 'Butler', 'Bachelor', 66, 'Louisiana'),
#  (419, 22, 1.69, 88.0, 5, 'Groundsman', 'PhD', 72, 'Alaska'),
#  (420, 32, 1.68, 43.0, 0, 'Orthoptist', 'Master', 88, 'South Dakota'),
#  (421, 45, 1.63, 46.0, 0, 'Ice Cream Vendor', 'Master', 68, 'South Dakota'),
#  (422, 46, 1.78, 64.0, 0, 'Area Manager', 'Bachelor', 70, 'Alaska'),
#  (423, 19, 1.55, 76.0, 2, 'Radio Controller', 'Bachelor', 66, 'Alaska'),
#  (424, 21, 1.69, 43.0, 5, 'Wood Worker', 'Bachelor', 74, 'Alaska'),
#  (425, 41, 1.84, 48.0, 1, 'Merchant Banker', 'Master', 78, 'Delaware'),
#  (426, 33, 1.57, 48.0, 3, 'Mill Operator', 'Master', 81, 'West Virginia'),
#  (427, 54, 1.89, 61.0, 2, 'Marble Mason', 'PhD', 86, 'Delaware'),
#  (428, 28, 1.81, 67.0, 0, 'Gambler', 'Master', 70, 'South Dakota'),
#  (429, 57, 1.7, 77.0, 3, 'Physicist', 'Master', 77, 'Louisiana'),
#  (430, 61, 1.91, 79.0, 4, 'Gamekeeper', 'Master', 72, 'West Virginia'),
#  (431, 55, 1.97, 50.0, 3, 'Panel Beater', 'Bachelor', 69, 'Delaware'),
#  (432, 47, 1.66, 85.0, 5, 'Technical Director', 'PhD', 85, 'Alaska'),
#  (433, 47, 1.69, 90.0, 3, 'Professional Wrestler', 'Bachelor', 73, 'South Dakota'),
#  (434, 47, 2.0, 49.0, 5, 'Warehouse Manager', 'Bachelor', 74, 'Louisiana'),
#  (435, 28, 1.85, 66.0, 2, 'Bus Company', 'Master', 67, 'West Virginia'),
#  (436, 40, 1.82, 53.0, 2, 'Groundsman', 'PhD', 83, 'Alaska'),
#  (437, 58, 1.69, 66.0, 4, 'Tank Farm Operative', 'PhD', 78, 'Alaska'),
#  (438, 47, 1.75, 82.0, 3, 'Vehicle Technician', 'Bachelor', 74, 'Delaware'),
#  (439, 42, 1.95, 72.0, 4, 'Cargo Operator', 'Bachelor', 80, 'South Dakota'),
#  (440, 33, 1.83, 48.0, 5, 'Balloonist', 'PhD', 77, 'Louisiana'),
#  (441, 40, 1.88, 88.0, 3, 'Civil Servant', 'Bachelor', 83, 'Alaska'),
#  (442, 62, 1.61, 85.0, 4, 'Wine Merchant', 'PhD', 74, 'South Dakota'),
#  (443, 60, 1.69, 67.0, 5, 'Telex Operator', 'Bachelor', 77, 'Alaska'),
#  (444, 18, 1.74, 56.0, 3, 'Carpenter', 'Bachelor', 83, 'South Dakota'),
#  (445, 56, 1.66, 67.0, 1, 'Training Officer', 'Master', 88, 'West Virginia'),
#  (446, 36, 1.55, 84.0, 5, 'Special Needs', 'Master', 89, 'Delaware'),
#  (447, 56, 1.52, 83.0, 0, 'Applications Engineer', 'Master', 90, 'Alaska'),
#  (448, 32, 1.9, 85.0, 1, 'Trade Union Official', 'Bachelor', 85, 'Delaware'),
#  (449, 57, 1.67, 65.0, 3, 'Literary Agent', 'Master', 73, 'Delaware'),
#  (450, 58, 1.82, 65.0, 3, 'Art Restorer', 'PhD', 68, 'South Dakota'),
#  (451, 37, 1.8, 62.0, 0, 'Landworker', 'Bachelor', 90, 'West Virginia'),
#  (452, 20, 1.85, 88.0, 0, 'Chiropractor', 'PhD', 83, 'Alaska'),
#  (453, 64, 1.66, 67.0, 0, 'Medical Advisor', 'PhD', 69, 'South Dakota'),
#  (454, 36, 1.98, 58.0, 4, 'Radiologist', 'PhD', 75, 'West Virginia'),
#  (455, 29, 1.56, 60.0, 3, 'Horse Trader', 'PhD', 71, 'Delaware'),
#  (456, 52, 1.81, 43.0, 5, 'Furniture Restorer', 'Master', 76, 'Louisiana'),
#  (457, 50, 1.65, 49.0, 2, 'Gas Mechanic', 'PhD', 73, 'Delaware'),
#  (458, 34, 1.8, 74.0, 3, 'Screen Printer', 'Bachelor', 80, 'Alaska'),
#  (459, 65, 1.77, 79.0, 1, 'Welfare Rights Officer', 'Bachelor', 75, 'South Dakota'),
#  (460, 47, 1.57, 58.0, 3, 'Blind Assembler', 'Master', 67, 'Delaware'),
#  (461, 66, 1.57, 90.0, 3, 'Yard Manager', 'PhD', 72, 'West Virginia'),
#  (462, 53, 1.84, 64.0, 5, 'Signwriter', 'Master', 76, 'South Dakota'),
#  (463, 43, 1.78, 88.0, 1, 'Nuclear Scientist', 'Bachelor', 65, 'Alaska'),
#  (464, 52, 1.77, 48.0, 3, 'Telecommunications', 'PhD', 68, 'West Virginia'),
#  (465, 41, 1.79, 55.0, 4, 'Project Engineer', 'PhD', 86, 'Alaska'),
#  (466, 55, 1.86, 72.0, 1, 'Seaman', 'Bachelor', 77, 'Alaska'),
#  (467, 24, 1.94, 40.0, 3, 'Medical Assistant', 'Master', 86, 'Delaware'),
#  (468, 48, 1.93, 45.0, 1, 'Labelling Operator', 'PhD', 65, 'Louisiana'),
#  (469, 53, 1.86, 78.0, 3, 'Highway Inspector', 'PhD', 75, 'Louisiana'),
#  (470, 32, 1.6, 51.0, 0, 'Potter', 'PhD', 85, 'South Dakota'),
#  (471, 58, 1.77, 58.0, 5, 'Nun', 'Master', 79, 'Alaska'),
#  (472, 59, 1.93, 81.0, 0, 'Gambler', 'Master', 78, 'South Dakota'),
#  (473, 26, 1.93, 46.0, 5, 'Furnace Man', 'Bachelor', 66, 'South Dakota'),
#  (474, 37, 1.66, 53.0, 5, 'Reflexologist', 'Master', 80, 'South Dakota'),
#  (475, 24, 1.82, 78.0, 3, 'Public House Manager', 'Master', 72, 'Louisiana'),
#  (476, 26, 1.9, 87.0, 0, 'Resin Caster', 'PhD', 77, 'West Virginia'),
#  (477, 41, 1.97, 61.0, 3, 'Technical Advisor', 'Master', 86, 'Louisiana'),
#  (478, 44, 1.89, 84.0, 0, 'Stage Hand', 'PhD', 83, 'Delaware'),
#  (479, 44, 1.53, 72.0, 3, 'Lawyer', 'Master', 85, 'South Dakota'),
#  (480, 49, 1.63, 56.0, 2, 'Violinist', 'PhD', 84, 'West Virginia'),
#  (481, 35, 1.93, 88.0, 2, 'Barman', 'Bachelor', 66, 'Alaska'),
#  (482, 31, 1.89, 67.0, 0, 'Food Processor', 'Bachelor', 79, 'West Virginia'),
#  (483, 33, 1.5, 65.0, 1, 'Funeral Furnisher', 'PhD', 76, 'South Dakota'),
#  (484, 61, 1.94, 55.0, 0, 'Producer', 'Master', 76, 'Louisiana'),
#  (485, 59, 1.83, 79.0, 1, 'Biochemist', 'Master', 76, 'South Dakota'),
#  (486, 43, 1.85, 52.0, 3, 'Catering Manager', 'PhD', 73, 'Delaware'),
#  (487, 25, 1.61, 42.0, 1, 'Lift Attendant', 'PhD', 79, 'South Dakota'),
#  (488, 60, 1.5, 59.0, 0, 'Scientist', 'PhD', 71, 'Louisiana'),
#  (489, 19, 1.54, 62.0, 0, 'Choreographer', 'Bachelor', 66, 'Alaska'),
#  (490, 33, 1.94, 46.0, 3, 'Furniture Dealer', 'PhD', 69, 'Louisiana'),
#  (491, 31, 1.77, 38.0, 4, 'Hearing Therapist', 'Master', 67, 'Louisiana'),
#  (492, 31, 1.61, 85.0, 1, 'Royal Marine', 'PhD', 83, 'Delaware'),
#  (493, 32, 1.61, 44.0, 1, 'Flying Instructor', 'PhD', 75, 'Delaware'),
#  (494, 56, 1.98, 58.0, 1, 'Marine Consultant', 'Master', 65, 'Alaska'),
#  (495, 27, 1.78, 76.0, 5, 'Motor Fitter', 'PhD', 69, 'Louisiana'),
#  (496, 34, 1.92, 57.0, 1, 'Trainee Manager', 'PhD', 90, 'Delaware'),
#  (497, 25, 1.87, 56.0, 5, 'Blinds Installer', 'Bachelor', 86, 'South Dakota'),
#  (498, 26, 1.56, 69.0, 5, 'Bus Valeter', 'PhD', 65, 'Alaska'),
#  (499, 33, 1.97, 46.0, 3, 'School Crossing', 'Master', 83, 'Alaska'),
#  (500, 19, 1.59, 68.0, 0, 'Airport Manager', 'PhD', 70, 'Alaska'),
#  (501, 21, 1.63, 40.0, 0, 'Repairer', 'PhD', 69, 'West Virginia'),
#  (502, 51, 1.86, 87.0, 3, 'Screen Writer', 'PhD', 68, 'South Dakota'),
#  (503, 48, 1.82, 72.0, 4, 'Grocer', 'Master', 79, 'Alaska'),
#  (504, 50, 1.54, 51.0, 1, 'Typewriter Engineer', 'Master', 83, 'South Dakota'),
#  (505, 46, 1.82, 79.0, 5, 'Building Estimator', 'Master', 81, 'Delaware'),
#  (506, 57, 1.98, 53.0, 0, 'Make Up Artist', 'Bachelor', 66, 'Louisiana'),
#  (507, 37, 1.73, 76.0, 0, 'Outdoor Pursuits', 'PhD', 79, 'South Dakota'),
#  (508, 21, 1.51, 46.0, 5, 'Aerial Erector', 'Bachelor', 80, 'West Virginia'),
#  (509, 45, 1.67, 71.0, 5, 'Maths Teacher', 'Bachelor', 86, 'South Dakota'),
#  (510, 49, 1.87, 55.0, 5, 'English Teacher', 'Bachelor', 87, 'West Virginia'),
#  (511, 22, 1.71, 71.0, 0, 'Medical Assistant', 'PhD', 67, 'Alaska'),
#  (512, 56, 1.73, 61.0, 0, 'Television Producer', 'PhD', 69, 'South Dakota'),
#  (513, 26, 1.58, 87.0, 0, 'Economist', 'Bachelor', 73, 'Louisiana'),
#  (514, 58, 1.52, 38.0, 1, 'Baptist Minister', 'Master', 83, 'Louisiana'),
#  (515, 63, 1.96, 49.0, 0, 'Weighbridge Operator', 'PhD', 75, 'West Virginia'),
#  (516, 56, 1.66, 64.0, 5, 'Patent Agent', 'Master', 81, 'Alaska'),
#  (517, 47, 1.69, 70.0, 5, 'Biologist', 'Bachelor', 81, 'Louisiana'),
#  (518, 45, 1.76, 40.0, 3, 'Bus Company', 'Master', 68, 'South Dakota'),
#  (519, 59, 1.92, 58.0, 0, 'Weighbridge Operator', 'Master', 85, 'Louisiana'),
#  (520, 64, 1.6, 74.0, 2, 'Magistrate', 'Master', 71, 'West Virginia'),
#  (521, 46, 1.99, 87.0, 1, 'Violin Maker', 'Bachelor', 72, 'West Virginia'),
#  (522, 39, 1.97, 39.0, 1, 'Van Driver', 'Master', 79, 'West Virginia'),
#  (523, 44, 1.67, 86.0, 5, 'Publican', 'PhD', 88, 'South Dakota'),
#  (524, 38, 1.6, 53.0, 3, 'Technical Engineer', 'Bachelor', 78, 'Alaska'),
#  (525, 60, 1.64, 40.0, 1, 'Training Consultant', 'Master', 73, 'Alaska'),
#  (526, 27, 1.99, 43.0, 4, 'Charge Hand', 'PhD', 86, 'West Virginia'),
#  (527, 22, 1.91, 42.0, 4, 'Brewery Worker', 'Master', 67, 'South Dakota'),
#  (528, 23, 1.65, 58.0, 3, 'Pest Controller', 'Master', 78, 'South Dakota'),
#  (529, 65, 1.62, 50.0, 1, 'Clergyman', 'Bachelor', 88, 'Alaska'),
#  (530, 26, 1.72, 58.0, 3, 'Floor Layer', 'PhD', 82, 'South Dakota'),
#  (531, 55, 1.89, 66.0, 2, 'Steward', 'Master', 82, 'Louisiana'),
#  (532, 39, 1.58, 81.0, 2, 'Auxiliary Nurse', 'Bachelor', 86, 'South Dakota'),
#  (533, 44, 1.55, 53.0, 2, 'Remedial Therapist', 'PhD', 76, 'West Virginia'),
#  (534, 64, 1.65, 90.0, 1, 'Assembly Worker', 'Master', 66, 'Alaska'),
#  (535, 56, 1.87, 53.0, 0, 'Steeplejack', 'Bachelor', 74, 'Alaska'),
#  (536, 24, 1.51, 87.0, 1, 'Fuel Merchant', 'Bachelor', 83, 'Louisiana'),
#  (537, 31, 1.84, 79.0, 0, 'Maths Teacher', 'Bachelor', 69, 'West Virginia'),
#  (538, 32, 1.6, 79.0, 3, 'Foundry Worker', 'Bachelor', 68, 'Alaska'),
#  (539, 53, 1.52, 67.0, 0, 'Home Economist', 'PhD', 76, 'South Dakota'),
#  (540, 66, 1.86, 69.0, 0, 'Quality Technician', 'PhD', 73, 'Louisiana'),
#  (541, 32, 1.68, 49.0, 2, 'Minicab Driver', 'Master', 90, 'West Virginia'),
#  (542, 53, 1.81, 77.0, 1, 'Nurseryman', 'Master', 89, 'Louisiana'),
#  (543, 57, 1.78, 41.0, 0, 'Minibus Driver', 'Master', 86, 'Louisiana'),
#  (544, 19, 1.6, 89.0, 4, 'Marine Geologist', 'PhD', 84, 'Alaska'),
#  (545, 19, 1.51, 62.0, 5, 'Probation Worker', 'Master', 70, 'Alaska'),
#  (546, 62, 1.74, 74.0, 4, 'Patrolman', 'Master', 89, 'Alaska'),
#  (547, 39, 1.51, 76.0, 1, 'Artexer', 'Master', 76, 'South Dakota'),
#  (548, 29, 2.0, 71.0, 2, 'Lithographer', 'Bachelor', 69, 'Louisiana'),
#  (549, 60, 1.83, 55.0, 4, 'Bodyguard', 'Bachelor', 77, 'South Dakota'),
#  (550, 27, 1.97, 49.0, 1, 'Lorry Driver', 'PhD', 88, 'South Dakota'),
#  (551, 23, 1.87, 60.0, 4, 'Art Dealer', 'PhD', 88, 'Louisiana'),
#  (552, 31, 1.78, 47.0, 4, 'Immigration Officer', 'Master', 77, 'West Virginia'),
#  (553, 47, 1.59, 40.0, 0, 'Bodyshop', 'Bachelor', 75, 'Delaware'),
#  (554, 41, 1.76, 38.0, 2, 'Investment Banker', 'Bachelor', 74, 'Alaska'),
#  (555, 67, 1.59, 89.0, 2, 'Bookmaker', 'Bachelor', 83, 'Louisiana'),
#  (556, 23, 1.85, 47.0, 0, 'Travel Agent', 'Master', 66, 'Delaware'),
#  (557, 28, 1.85, 80.0, 3, 'China Restorer', 'Master', 89, 'Louisiana'),
#  (558, 21, 1.57, 48.0, 5, 'Shipyard Worker', 'PhD', 86, 'South Dakota'),
#  (559, 35, 1.66, 83.0, 4, 'Printer', 'Bachelor', 79, 'West Virginia'),
#  (560, 49, 1.65, 82.0, 2, 'Fork Lift Truck Driver', 'Bachelor', 84, 'West Virginia'),
#  (561, 44, 1.85, 74.0, 3, 'Assistant Caretaker', 'Bachelor', 73, 'Delaware'),
#  (562, 66, 1.9, 77.0, 1, 'Circus Proprietor', 'Master', 81, 'South Dakota'),
#  (563, 40, 1.87, 53.0, 2, 'Pastry Chef', 'Bachelor', 78, 'South Dakota'),
#  (564, 36, 1.85, 78.0, 5, 'Pipe Insulator', 'Master', 86, 'Louisiana'),
#  (565, 49, 1.6, 82.0, 0, 'Postwoman', 'Master', 81, 'Alaska'),
#  (566, 20, 1.5, 62.0, 3, 'Saw Miller', 'Bachelor', 72, 'West Virginia'),
#  (567, 56, 1.94, 60.0, 4, 'Public House Manager', 'Bachelor', 66, 'South Dakota'),
#  (568, 31, 1.93, 79.0, 5, 'Licensing', 'Bachelor', 74, 'Delaware'),
#  (569, 67, 1.9, 40.0, 2, 'Analyst', 'Master', 69, 'Alaska'),
#  (570, 36, 1.55, 59.0, 1, 'Public House Manager', 'Bachelor', 75, 'South Dakota'),
#  (571, 18, 1.97, 43.0, 2, 'Tax Consultant', 'PhD', 80, 'West Virginia'),
#  (572, 29, 1.97, 48.0, 4, 'Ship Broker', 'Bachelor', 69, 'West Virginia'),
#  (573, 52, 1.67, 50.0, 3, 'Welfare Assistant', 'PhD', 87, 'Delaware'),
#  (574, 50, 1.83, 57.0, 1, 'Charity Worker', 'Bachelor', 82, 'Alaska'),
#  (575, 22, 1.77, 69.0, 1, 'Blinds Installer', 'Master', 77, 'South Dakota'),
#  (576, 45, 1.54, 90.0, 5, 'Tanner', 'Bachelor', 65, 'West Virginia'),
#  (577, 22, 1.6, 78.0, 2, 'Car Valet', 'Master', 75, 'Louisiana'),
#  (578, 45, 1.89, 68.0, 3, 'Medical Practitioner', 'Bachelor', 83, 'West Virginia'),
#  (579, 63, 1.59, 62.0, 2, 'IT Trainer', 'Master', 85, 'West Virginia'),
#  (580, 36, 1.72, 54.0, 1, 'Merchant Banker', 'PhD', 68, 'West Virginia'),
#  (581, 19, 1.88, 80.0, 0, 'Carpenter', 'PhD', 75, 'Delaware'),
#  (582, 57, 1.77, 86.0, 4, 'Lighterman', 'PhD', 79, 'Alaska'),
#  (583, 23, 1.69, 71.0, 3, 'Tutor', 'PhD', 78, 'South Dakota'),
#  (584, 33, 1.94, 68.0, 2, 'Camera Repairer', 'Master', 78, 'Louisiana'),
#  (585, 43, 1.79, 71.0, 4, 'Golf Club Professional', 'Bachelor', 81, 'South Dakota'),
#  (586, 43, 1.97, 48.0, 1, 'Instructor', 'Bachelor', 74, 'Alaska'),
#  (587, 32, 1.54, 81.0, 3, 'Investment Manager', 'PhD', 75, 'Delaware'),
#  (588, 22, 1.8, 58.0, 5, 'Building Inspector', 'Bachelor', 81, 'South Dakota'),
#  (589, 51, 1.7, 58.0, 2, 'Training Consultant', 'Master', 81, 'Delaware'),
#  (590, 67, 1.85, 75.0, 4, 'Saw Miller', 'Bachelor', 76, 'Alaska'),
#  (591, 64, 1.57, 75.0, 4, 'Chimney Sweep', 'Bachelor', 85, 'Delaware'),
#  (592, 33, 1.64, 72.0, 2, 'Roofer', 'Master', 68, 'Delaware'),
#  (593, 34, 1.74, 76.0, 3, 'Auctioneer', 'Bachelor', 71, 'Delaware'),
#  (594, 56, 1.57, 76.0, 5, 'Research Scientist', 'Bachelor', 69, 'South Dakota'),
#  (595, 29, 1.94, 82.0, 1, 'Barrister', 'PhD', 89, 'West Virginia'),
#  (596, 47, 1.63, 61.0, 0, 'Planning Officer', 'Master', 89, 'Louisiana'),
#  (597, 66, 1.92, 82.0, 5, 'Chemist', 'Bachelor', 83, 'West Virginia'),
#  (598, 61, 1.99, 66.0, 2, 'Merchant Seaman', 'PhD', 83, 'Louisiana'),
#  (599, 38, 1.82, 50.0, 3, 'Laminator', 'Master', 85, 'Alaska'),
#  (600, 27, 1.76, 61.0, 0, 'Trade Mark Agent', 'Bachelor', 79, 'South Dakota'),
#  (601, 48, 1.85, 63.0, 1, 'Transport Engineer', 'PhD', 79, 'Alaska'),
#  (602, 35, 1.6, 50.0, 0, 'Marine Geologist', 'Bachelor', 83, 'South Dakota'),
#  (603, 40, 1.96, 83.0, 1, 'Midwife', 'Master', 81, 'South Dakota'),
#  (604, 37, 1.7, 45.0, 5, 'Arts', 'Bachelor', 79, 'West Virginia'),
#  (605, 20, 1.8, 49.0, 3, 'Watchmaker', 'Master', 66, 'Alaska'),
#  (606, 36, 1.92, 54.0, 5, 'Catering Consultant', 'Master', 67, 'South Dakota'),
#  (607, 57, 1.52, 74.0, 1, 'Legal Executive', 'PhD', 84, 'Louisiana'),
#  (608, 42, 1.6, 79.0, 3, 'Toy Trader', 'Bachelor', 79, 'Louisiana'),
#  (609, 53, 1.96, 79.0, 1, 'Advertising Assistant', 'Bachelor', 90, 'South Dakota'),
#  (610, 46, 1.9, 57.0, 5, 'Milklady', 'Master', 90, 'Louisiana'),
#  (611, 59, 1.67, 54.0, 1, 'Stone Cutter', 'Master', 71, 'Alaska'),
#  (612, 56, 1.81, 75.0, 0, 'Administrator', 'PhD', 80, 'Louisiana'),
#  (613, 27, 1.82, 76.0, 2, 'Off Shore', 'PhD', 66, 'West Virginia'),
#  (614, 24, 1.53, 55.0, 5, 'Payroll Manager', 'Master', 90, 'Alaska'),
#  (615, 63, 1.86, 79.0, 2, 'Immigration Officer', 'Bachelor', 67, 'Louisiana'),
#  (616, 59, 1.62, 41.0, 4, 'Restaurateur', 'PhD', 70, 'South Dakota'),
#  (617, 33, 1.57, 39.0, 5, 'Telephonist', 'Master', 87, 'West Virginia'),
#  (618, 46, 1.71, 62.0, 5, 'Astronomer', 'PhD', 81, 'Louisiana'),
#  (619, 57, 1.86, 52.0, 5, 'Turkey Farmer', 'PhD', 70, 'Alaska'),
#  (620, 41, 1.97, 60.0, 4, 'Oil Broker', 'Bachelor', 74, 'West Virginia'),
#  (621, 44, 1.55, 46.0, 5, 'Mathematician', 'PhD', 89, 'Alaska'),
#  (622, 61, 1.84, 59.0, 5, 'Cashier', 'Bachelor', 84, 'South Dakota'),
#  (623, 58, 1.87, 57.0, 3, 'Piano Tuner', 'Master', 85, 'Alaska'),
#  (624, 22, 1.65, 45.0, 3, 'Blind Assembler', 'PhD', 75, 'South Dakota'),
#  (625, 53, 1.94, 70.0, 0, 'Quality Inspector', 'PhD', 86, 'West Virginia'),
#  (626, 36, 1.53, 47.0, 1, 'Investigator', 'Master', 73, 'Louisiana'),
#  (627, 27, 1.95, 67.0, 1, 'Park Ranger', 'PhD', 75, 'South Dakota'),
#  (628, 55, 1.54, 59.0, 5, 'Hospital Orderly', 'Master', 86, 'Delaware'),
#  (629, 40, 1.73, 51.0, 1, 'Hardware Dealer', 'Master', 74, 'West Virginia'),
#  (630, 26, 1.81, 78.0, 3, 'Restaurant Manager', 'Master', 84, 'South Dakota'),
#  (631, 37, 1.5, 72.0, 1, 'Psychiatrist', 'Bachelor', 82, 'West Virginia'),
#  (632, 59, 1.92, 50.0, 0, 'Actuary', 'PhD', 90, 'Alaska'),
#  (633, 26, 1.85, 60.0, 2, 'Fraud Investigator', 'Bachelor', 86, 'Louisiana'),
#  (634, 23, 1.79, 48.0, 0, 'Bank Messenger', 'Master', 85, 'West Virginia'),
#  (635, 50, 1.86, 76.0, 4, 'Planning Officer', 'Master', 76, 'South Dakota'),
#  (636, 41, 2.0, 69.0, 2, 'Immigration Officer', 'Bachelor', 74, 'Delaware'),
#  (637, 31, 1.61, 84.0, 1, 'Laminator', 'PhD', 75, 'West Virginia'),
#  (638, 30, 1.75, 45.0, 2, 'Auctioneer', 'Master', 72, 'Delaware'),
#  (639, 27, 1.77, 41.0, 4, 'Barmaid', 'PhD', 67, 'Alaska'),
#  (640, 24, 1.92, 41.0, 5, 'Editor', 'Master', 81, 'Louisiana'),
#  (641, 65, 1.56, 54.0, 3, 'Groom', 'Bachelor', 81, 'South Dakota'),
#  (642, 60, 1.71, 44.0, 5, 'Training Instructor', 'Master', 75, 'Louisiana'),
#  (643, 26, 1.92, 44.0, 4, 'English Teacher', 'Master', 84, 'West Virginia'),
#  (644, 27, 1.55, 50.0, 4, 'Inventor', 'Master', 70, 'Delaware'),
#  (645, 62, 1.6, 83.0, 3, 'Nurseryman', 'Bachelor', 89, 'Louisiana'),
#  (646, 28, 1.75, 51.0, 5, 'Tattooist', 'Master', 88, 'West Virginia'),
#  (647, 20, 1.51, 43.0, 0, 'Technical Manager', 'Bachelor', 78, 'Alaska'),
#  (648, 61, 1.76, 84.0, 5, 'Chiropodist', 'Master', 88, 'Delaware'),
#  (649, 46, 1.99, 56.0, 2, 'Stock Controller', 'Bachelor', 84, 'Alaska'),
#  (650, 66, 1.59, 40.0, 2, 'Produce Supervisor', 'PhD', 88, 'West Virginia'),
#  (651, 32, 1.87, 44.0, 0, 'Advertising Contractor', 'Bachelor', 82, 'Delaware'),
#  (652, 37, 1.68, 66.0, 4, 'Merchant', 'PhD', 90, 'West Virginia'),
#  (653, 30, 1.91, 49.0, 0, 'Research Consultant', 'Master', 76, 'Louisiana'),
#  (654, 46, 1.92, 82.0, 3, 'Scientific Officer', 'PhD', 79, 'Alaska'),
#  (655, 67, 1.57, 84.0, 0, 'Hawker', 'Bachelor', 77, 'Louisiana'),
#  (656, 51, 1.8, 89.0, 4, 'Shooting Instructor', 'Bachelor', 78, 'Delaware'),
#  (657, 30, 1.68, 39.0, 5, 'Fuel Merchant', 'Master', 90, 'Louisiana'),
#  (658, 26, 1.94, 66.0, 0, 'Broadcaster', 'Master', 73, 'South Dakota'),
#  (659, 59, 1.85, 81.0, 4, 'Library Manager', 'PhD', 80, 'Alaska'),
#  (660, 53, 1.76, 82.0, 4, 'Charge Hand', 'Master', 68, 'Louisiana'),
#  (661, 25, 1.67, 81.0, 5, 'Radio Controller', 'Bachelor', 74, 'South Dakota'),
#  (662, 66, 1.82, 48.0, 4, 'Street Entertainer', 'Master', 70, 'Alaska'),
#  (663, 46, 1.88, 58.0, 1, 'Piano Teacher', 'Master', 81, 'Delaware'),
#  (664, 45, 1.61, 79.0, 3, 'Resin Caster', 'Bachelor', 67, 'Delaware'),
#  (665, 46, 1.72, 74.0, 3, 'Cartographer', 'Master', 76, 'South Dakota'),
#  (666, 44, 1.56, 69.0, 5, 'Ambulance Controller', 'Bachelor', 66, 'West Virginia'),
#  (667, 50, 1.52, 73.0, 0, 'Catering Manager', 'PhD', 76, 'Delaware'),
#  (668, 42, 1.75, 51.0, 5, 'Spring Maker', 'Master', 67, 'Alaska'),
#  (669, 32, 1.53, 52.0, 3, 'Picture Editor', 'PhD', 65, 'Alaska'),
#  (670, 24, 1.83, 83.0, 3, 'Delivery Driver', 'Bachelor', 87, 'Alaska'),
#  (671, 27, 1.67, 78.0, 2, 'Voluntary Worker', 'PhD', 69, 'South Dakota'),
#  (672, 36, 1.55, 48.0, 3, 'Gardener', 'PhD', 80, 'Delaware'),
# ...
#  (776, 50, 1.8, 71.0, 5, 'Literary Agent', 'PhD', 85, 'Delaware'),
#  (777, 55, 1.52, 53.0, 5, 'Accountant', 'Bachelor', 83, 'Delaware'),
#  (778, 28, 1.89, 60.0, 5, 'Regulator', 'Master', 86, 'Louisiana'),
#  (779, 64, 1.51, 83.0, 0, 'Caterer', 'PhD', 84, 'Alaska'),
#  (780, 54, 1.91, 75.0, 2, 'Pools Collector', 'Master', 66, 'South Dakota'),
#  (781, 23, 1.98, 67.0, 3, 'Acupuncturist', 'Master', 66, 'Louisiana'),
#  (782, 34, 1.75, 73.0, 0, 'Textile Worker', 'Master', 85, 'Delaware'),
#  (783, 67, 1.56, 70.0, 2, 'Tyre Fitter', 'PhD', 83, 'West Virginia'),
#  (784, 57, 1.72, 62.0, 4, 'Tax Manager', 'Bachelor', 85, 'South Dakota'),
#  (785, 49, 1.89, 81.0, 3, 'Art Critic', 'Master', 85, 'Louisiana'),
#  (786, 36, 1.53, 78.0, 1, 'Line Manager', 'Master', 85, 'Alaska'),
#  (787, 48, 1.68, 72.0, 0, 'Medical Consultant', 'Bachelor', 72, 'West Virginia'),
#  (788, 37, 1.7, 85.0, 2, 'Cable Jointer', 'PhD', 79, 'South Dakota'),
#  (789, 62, 1.66, 51.0, 4, 'Merchant Seaman', 'Bachelor', 66, 'Delaware'),
#  (790, 46, 1.87, 53.0, 5, 'Magician', 'Master', 78, 'West Virginia'),
#  (791, 47, 1.6, 53.0, 4, 'Print Finisher', 'Bachelor', 71, 'Alaska'),
#  (792, 56, 1.96, 81.0, 5, 'Technical Illustrator', 'PhD', 69, 'Alaska'),
#  (793, 63, 1.93, 40.0, 3, 'Property Developer', 'PhD', 75, 'Alaska'),
#  (794, 43, 1.95, 74.0, 2, 'Technical Director', 'Bachelor', 69, 'Alaska'),
#  (795, 50, 1.7, 86.0, 4, 'Foster Parent', 'Bachelor', 82, 'South Dakota'),
#  (796, 38, 1.71, 72.0, 0, 'Textile Technician', 'Master', 72, 'West Virginia'),
#  (797, 25, 1.84, 49.0, 3, 'Fireman', 'PhD', 73, 'West Virginia'),
#  (798, 33, 1.66, 38.0, 0, 'Labourer', 'Master', 69, 'South Dakota'),
#  (799, 21, 1.68, 54.0, 1, 'Waiter', 'Master', 74, 'West Virginia'),
#  (800, 57, 1.74, 77.0, 2, 'Progress Clerk', 'Bachelor', 78, 'Delaware'),
#  (801, 28, 1.61, 82.0, 2, 'Professional Wrestler', 'Master', 75, 'Louisiana'),
#  (802, 64, 1.59, 46.0, 4, 'Lighting Technician', 'Bachelor', 75, 'Delaware'),
#  (803, 66, 1.62, 65.0, 3, 'Insurance Broker', 'Bachelor', 70, 'West Virginia'),
#  (804, 50, 1.9, 49.0, 3, 'Television Producer', 'Bachelor', 79, 'West Virginia'),
#  (805, 37, 1.86, 88.0, 3, 'Oil Broker', 'Master', 80, 'South Dakota'),
#  (806, 23, 1.55, 48.0, 0, 'Laundry Staff', 'Master', 77, 'Louisiana'),
#  (807, 47, 1.81, 66.0, 5, 'Pipe Fitter', 'Master', 72, 'Delaware'),
#  (808, 55, 1.78, 89.0, 2, 'Playgroup Assistant', 'Bachelor', 76, 'South Dakota'),
#  (809, 21, 1.68, 81.0, 4, 'Interpreter', 'PhD', 74, 'West Virginia'),
#  (810, 56, 1.99, 56.0, 2, 'Payroll Manager', 'PhD', 85, 'West Virginia'),
#  (811, 36, 1.89, 66.0, 0, 'Quality Engineer', 'PhD', 82, 'South Dakota'),
#  (812, 24, 1.82, 47.0, 1, 'Planning Manager', 'Master', 78, 'Delaware'),
#  (813, 34, 1.95, 43.0, 1, 'Plater', 'Bachelor', 88, 'Alaska'),
#  (814, 66, 1.83, 83.0, 2, 'Regulator', 'Master', 77, 'Alaska'),
#  (815, 20, 1.93, 61.0, 5, 'Training Manager', 'Master', 77, 'South Dakota'),
#  (816, 54, 1.59, 39.0, 1, 'Lock Keeper', 'PhD', 82, 'Delaware'),
#  (817, 41, 1.87, 85.0, 0, 'Labourer', 'Bachelor', 82, 'Alaska'),
#  (818, 22, 1.55, 68.0, 4, 'Blind Fitter', 'Bachelor', 77, 'Louisiana'),
#  (819, 46, 1.88, 43.0, 0, 'Medical Advisor', 'PhD', 89, 'Louisiana'),
#  (820, 35, 1.83, 62.0, 2, 'Lime Kiln Attendant', 'Bachelor', 84, 'Louisiana'),
#  (821, 25, 1.81, 46.0, 4, 'Hop Merchant', 'Bachelor', 69, 'South Dakota'),
#  (822, 43, 1.68, 58.0, 3, 'Stone Sawyer', 'PhD', 76, 'Alaska'),
#  (823, 53, 1.72, 82.0, 4, 'Hospital Orderly', 'PhD', 76, 'Delaware'),
#  (824, 30, 1.87, 74.0, 3, 'Transport Controller', 'PhD', 84, 'Louisiana'),
#  (825, 43, 1.95, 68.0, 4, 'Lighterman', 'Bachelor', 81, 'South Dakota'),
#  (826, 20, 1.68, 54.0, 1, 'Optical Advisor', 'Bachelor', 66, 'Delaware'),
#  (827, 63, 1.91, 46.0, 2, 'Museum Assistant', 'Master', 75, 'West Virginia'),
#  (828, 51, 1.84, 69.0, 3, 'Office Worker', 'Bachelor', 79, 'Delaware'),
#  (829, 56, 1.65, 52.0, 0, 'Wages Clerk', 'Master', 81, 'Delaware'),
#  (830, 38, 1.94, 65.0, 3, 'Marine Pilot', 'Bachelor', 84, 'Alaska'),
#  (831, 28, 1.69, 54.0, 0, 'Scientist', 'PhD', 77, 'Louisiana'),
#  (832, 65, 1.88, 77.0, 5, 'Metal Worker', 'Master', 74, 'Louisiana'),
#  (833, 39, 1.63, 50.0, 0, 'Housewife', 'Bachelor', 81, 'Louisiana'),
#  (834, 52, 1.82, 77.0, 3, 'Metallurgist', 'PhD', 80, 'Louisiana'),
#  (835, 37, 1.66, 47.0, 0, 'Turner', 'Bachelor', 80, 'South Dakota'),
#  (836, 41, 1.55, 55.0, 1, 'Shooting Instructor', 'PhD', 75, 'South Dakota'),
#  (837, 44, 1.55, 38.0, 3, 'Law Clerk', 'Master', 83, 'Alaska'),
#  (838, 64, 1.89, 69.0, 2, 'Stewardess', 'PhD', 87, 'South Dakota'),
#  (839, 56, 1.54, 86.0, 1, 'Bodyguard', 'Master', 80, 'Alaska'),
#  (840, 59, 1.77, 49.0, 1, 'Marine Surveyor', 'Master', 90, 'Louisiana'),
#  (841, 54, 1.99, 83.0, 1, 'Radio Controller', 'Master', 72, 'South Dakota'),
#  (842, 55, 2.0, 50.0, 3, 'Chambermaid', 'PhD', 80, 'Delaware'),
#  (843, 51, 1.69, 57.0, 2, 'Hardware Dealer', 'PhD', 85, 'Louisiana'),
#  (844, 67, 1.97, 71.0, 0, 'Marketing Assistant', 'Master', 77, 'Delaware'),
#  (845, 61, 1.68, 41.0, 5, 'Lawyer', 'Bachelor', 72, 'South Dakota'),
#  (846, 54, 1.72, 38.0, 1, 'Mill Operator', 'PhD', 87, 'South Dakota'),
#  (847, 30, 1.89, 38.0, 0, 'Surveyor', 'PhD', 65, 'West Virginia'),
#  (848, 38, 1.89, 53.0, 1, 'Television Producer', 'Bachelor', 78, 'Delaware'),
#  (849, 44, 1.98, 86.0, 5, 'Botanist', 'Bachelor', 87, 'Delaware'),
#  (850, 44, 1.58, 72.0, 0, 'Forensic Scientist', 'Master', 81, 'Louisiana'),
#  (851, 48, 1.99, 88.0, 5, 'Pools Collector', 'Master', 88, 'South Dakota'),
#  (852, 63, 1.84, 60.0, 5, 'Furrier', 'Master', 69, 'Louisiana'),
#  (853, 31, 1.85, 73.0, 2, 'Vehicle Body Worker', 'PhD', 82, 'Alaska'),
#  (854, 60, 1.78, 72.0, 2, 'Pawnbroker', 'PhD', 80, 'Louisiana'),
#  (855, 42, 1.93, 76.0, 4, 'Health And Safety', 'Bachelor', 75, 'Delaware'),
#  (856, 47, 1.72, 90.0, 2, 'Van Driver', 'Master', 82, 'Alaska'),
#  (857, 52, 1.89, 70.0, 3, 'Hypnotist', 'Bachelor', 76, 'Alaska'),
#  (858, 57, 1.81, 58.0, 5, 'Broadcaster', 'PhD', 80, 'Delaware'),
#  (859, 33, 1.69, 71.0, 5, 'Telephonist', 'PhD', 73, 'Louisiana'),
#  (860, 37, 1.64, 64.0, 5, 'Pattern Cutter', 'Bachelor', 72, 'Alaska'),
#  (861, 67, 1.83, 40.0, 1, 'Hospital Worker', 'Bachelor', 74, 'Delaware'),
#  (862, 62, 1.74, 44.0, 0, 'Radiologist', 'PhD', 87, 'West Virginia'),
#  (863, 38, 1.81, 75.0, 2, 'Barrister', 'Master', 80, 'Alaska'),
#  (864, 53, 1.86, 38.0, 1, 'Technical Editor', 'Bachelor', 90, 'Alaska'),
#  (865, 36, 1.82, 61.0, 4, 'Sales Engineer', 'Master', 68, 'Louisiana'),
#  (866, 61, 1.81, 71.0, 0, 'Bus Mechanic', 'Master', 82, 'West Virginia'),
#  (867, 43, 1.61, 71.0, 0, 'Chiropodist', 'PhD', 76, 'Delaware'),
#  (868, 36, 1.69, 50.0, 4, 'Marine Engineer', 'PhD', 66, 'Alaska'),
#  (869, 63, 1.87, 64.0, 5, 'Civil Servant', 'PhD', 67, 'Alaska'),
#  (870, 46, 1.73, 80.0, 3, 'Circus Proprietor', 'Bachelor', 85, 'Alaska'),
#  (871, 65, 1.7, 59.0, 5, 'Handyman', 'PhD', 80, 'Delaware'),
#  (872, 30, 1.68, 58.0, 4, 'Payroll Clerk', 'Master', 82, 'Alaska'),
#  (873, 53, 1.82, 90.0, 5, 'Pawnbroker', 'PhD', 87, 'Alaska'),
#  (874, 26, 1.77, 62.0, 4, 'Marketing Director', 'Master', 68, 'Louisiana'),
#  (875, 65, 1.98, 38.0, 5, 'Assistant Teacher', 'Master', 83, 'Delaware'),
#  (876, 33, 1.57, 57.0, 0, 'Oil Rig Crew', 'Bachelor', 66, 'Louisiana'),
#  (877, 32, 1.66, 87.0, 5, 'Mill Operator', 'PhD', 85, 'Delaware'),
#  (878, 21, 1.79, 74.0, 1, 'Chandler', 'Bachelor', 68, 'West Virginia'),
#  (879, 39, 1.58, 54.0, 2, 'Marine Pilot', 'Bachelor', 87, 'West Virginia'),
#  (880, 24, 1.65, 74.0, 3, 'Lawn Mower', 'PhD', 86, 'Delaware'),
#  (881, 18, 1.66, 68.0, 1, 'Technical Advisor', 'PhD', 82, 'Delaware'),
#  (882, 44, 1.82, 40.0, 5, 'Quality Inspector', 'Bachelor', 85, 'West Virginia'),
#  (883, 48, 1.89, 60.0, 3, 'Sales Manager', 'Bachelor', 85, 'Delaware'),
#  (884, 66, 1.83, 76.0, 0, 'Quality Technician', 'Bachelor', 74, 'Alaska'),
#  (885, 36, 1.52, 72.0, 4, 'Graphic Designer', 'Master', 85, 'South Dakota'),
#  (886, 67, 1.61, 41.0, 5, 'Reflexologist', 'Master', 67, 'Louisiana'),
#  (887, 32, 1.61, 56.0, 3, 'Goods Handler', 'Bachelor', 82, 'South Dakota'),
#  (888, 29, 1.74, 85.0, 0, 'Wages Clerk', 'Master', 78, 'Delaware'),
#  (889, 20, 1.7, 65.0, 5, 'Fuel Merchant', 'Bachelor', 77, 'West Virginia'),
#  (890, 29, 1.6, 63.0, 5, 'Insurance Broker', 'PhD', 88, 'Alaska'),
#  (891, 20, 1.62, 55.0, 3, 'Pawnbroker', 'PhD', 65, 'Alaska'),
#  (892, 54, 1.84, 65.0, 2, 'Portfolio Manager', 'Bachelor', 84, 'South Dakota'),
#  (893, 39, 1.8, 39.0, 2, 'Homecare Manager', 'Master', 74, 'West Virginia'),
#  (894, 59, 1.57, 40.0, 1, 'Interviewer', 'PhD', 82, 'Louisiana'),
#  (895, 49, 1.88, 43.0, 0, 'Blinds Installer', 'Bachelor', 69, 'Louisiana'),
#  (896, 47, 1.92, 56.0, 0, 'Plater', 'PhD', 73, 'Delaware'),
#  (897, 25, 1.73, 39.0, 2, 'Knitter', 'PhD', 75, 'Delaware'),
#  (898, 64, 1.6, 71.0, 2, 'Waiter', 'Master', 79, 'Alaska'),
#  (899, 63, 1.85, 39.0, 3, 'Travel Clerk', 'Bachelor', 70, 'South Dakota'),
#  (900, 65, 1.53, 50.0, 5, 'Metal Polisher', 'Bachelor', 75, 'Alaska'),
#  (901, 54, 1.97, 42.0, 3, 'Metal Polisher', 'PhD', 86, 'Delaware'),
#  (902, 29, 1.55, 56.0, 5, 'Radio Operator', 'Bachelor', 84, 'West Virginia'),
#  (903, 45, 1.99, 44.0, 2, 'Taxi Controller', 'PhD', 81, 'Alaska'),
#  (904, 23, 1.59, 70.0, 3, 'Writer', 'PhD', 77, 'South Dakota'),
#  (905, 29, 1.62, 71.0, 2, 'Pig Manager', 'Master', 69, 'West Virginia'),
#  (906, 38, 1.58, 60.0, 5, 'Preacher', 'Master', 72, 'South Dakota'),
#  (907, 34, 2.0, 70.0, 2, 'Brewery Manager', 'PhD', 77, 'Delaware'),
#  (908, 46, 1.69, 90.0, 0, 'Welfare Rights Officer', 'Master', 89, 'Alaska'),
#  (909, 39, 1.67, 63.0, 5, 'Gaming Club Proprietor', 'Bachelor', 74, 'Louisiana'),
#  (910, 64, 1.98, 77.0, 5, 'Lighterman', 'Master', 83, 'South Dakota'),
#  (911, 34, 1.58, 57.0, 4, 'Physicist', 'Master', 85, 'Alaska'),
#  (912, 62, 1.6, 46.0, 4, 'Valve Technician', 'PhD', 72, 'South Dakota'),
#  (913, 60, 1.57, 82.0, 5, 'Transport Controller', 'Bachelor', 68, 'West Virginia'),
#  (914, 37, 1.99, 47.0, 5, 'Handyman', 'Master', 70, 'West Virginia'),
#  (915, 61, 1.77, 84.0, 0, 'Hygienist', 'Master', 81, 'Alaska'),
#  (916, 62, 1.51, 58.0, 3, 'Rose Grower', 'Master', 68, 'Alaska'),
#  (917, 41, 1.97, 78.0, 5, 'Microbiologist', 'Bachelor', 84, 'Delaware'),
#  (918, 32, 1.57, 39.0, 4, 'Medical Supplier', 'PhD', 69, 'West Virginia'),
#  (919, 27, 1.62, 81.0, 0, 'Probation Worker', 'Bachelor', 79, 'Louisiana'),
#  (920, 41, 1.75, 76.0, 3, 'Psychoanalyst', 'Bachelor', 78, 'Louisiana'),
#  (921, 48, 1.74, 48.0, 1, 'Lift Attendant', 'Bachelor', 89, 'Louisiana'),
#  (922, 60, 1.98, 55.0, 3, 'Letting Agent', 'PhD', 71, 'Delaware'),
#  (923, 61, 1.6, 49.0, 3, 'Technical Clerk', 'PhD', 89, 'Louisiana'),
#  (924, 23, 1.73, 53.0, 3, 'Retired', 'Bachelor', 81, 'West Virginia'),
#  (925, 51, 1.66, 77.0, 5, 'Typewriter Engineer', 'PhD', 87, 'Alaska'),
#  (926, 22, 1.55, 67.0, 0, 'Map Mounter', 'PhD', 83, 'South Dakota'),
#  (927, 21, 1.99, 40.0, 4, 'Radio Producer', 'PhD', 82, 'Louisiana'),
#  (928, 30, 1.65, 63.0, 2, 'Motor Racing', 'Master', 83, 'Louisiana'),
#  (929, 27, 1.65, 41.0, 5, 'Traffic Warden', 'Bachelor', 70, 'Alaska'),
#  (930, 51, 1.82, 43.0, 5, 'Temperature Time', 'Bachelor', 79, 'South Dakota'),
#  (931, 61, 1.79, 82.0, 4, 'Gambler', 'Master', 71, 'Louisiana'),
#  (932, 49, 1.73, 49.0, 3, 'Investment Manager', 'Master', 67, 'Louisiana'),
#  (933, 46, 1.66, 79.0, 5, 'Health Visitor', 'PhD', 90, 'South Dakota'),
#  (934, 47, 1.56, 66.0, 5, 'Production Manager', 'Bachelor', 69, 'Louisiana'),
#  (935, 44, 1.69, 88.0, 4, 'Health Advisor', 'Master', 79, 'Louisiana'),
#  (936, 21, 1.52, 48.0, 2, 'Graphologist', 'Bachelor', 82, 'West Virginia'),
#  (937, 61, 1.88, 41.0, 3, 'Orthopaedic', 'Master', 90, 'Alaska'),
#  (938, 64, 1.81, 45.0, 1, 'Ironmonger', 'Bachelor', 65, 'West Virginia'),
#  (939, 34, 1.73, 69.0, 4, 'Administration Assistant', 'PhD', 65, 'Delaware'),
#  (940, 55, 1.61, 80.0, 3, 'Sports Coach', 'Master', 67, 'South Dakota'),
#  (941, 45, 1.8, 38.0, 1, 'Violinist', 'Master', 76, 'South Dakota'),
#  (942, 52, 1.59, 41.0, 5, 'Post Sorter', 'Bachelor', 66, 'South Dakota'),
#  (943, 48, 1.52, 74.0, 4, 'Off Shore', 'Master', 66, 'Alaska'),
#  (944, 44, 1.55, 49.0, 1, 'Motor Engineer', 'PhD', 70, 'Delaware'),
#  (945, 67, 1.73, 75.0, 2, 'Attendant', 'Bachelor', 85, 'West Virginia'),
#  (946, 41, 1.68, 62.0, 0, 'Security Guard', 'PhD', 77, 'West Virginia'),
#  (947, 42, 1.74, 45.0, 5, 'Military Leader', 'Master', 77, 'South Dakota'),
#  (948, 61, 1.76, 82.0, 1, 'Booking Agent', 'Bachelor', 86, 'Louisiana'),
#  (949, 26, 1.74, 82.0, 4, 'Museum Attendant', 'Master', 85, 'Alaska'),
#  (950, 25, 1.76, 77.0, 2, 'French Polisher', 'PhD', 70, 'Louisiana'),
#  (951, 43, 1.86, 69.0, 3, 'Hotel Consultant', 'PhD', 81, 'Delaware'),
#  (952, 64, 1.65, 50.0, 0, 'Entertainer', 'Bachelor', 72, 'South Dakota'),
#  (953, 66, 1.9, 85.0, 1, 'Sales Assistant', 'Master', 65, 'Alaska'),
#  (954, 47, 1.67, 89.0, 5, 'Land Agent', 'Bachelor', 86, 'Louisiana'),
#  (955, 45, 1.64, 88.0, 0, 'Orthopaedic', 'Master', 82, 'West Virginia'),
#  (956, 32, 1.66, 38.0, 0, 'Pig Man', 'Master', 72, 'West Virginia'),
#  (957, 40, 1.78, 39.0, 1, 'Instrument Supervisor', 'Master', 69, 'Alaska'),
#  (958, 30, 1.84, 68.0, 0, 'Gamekeeper', 'Master', 88, 'South Dakota'),
#  (959, 20, 1.73, 72.0, 2, 'Stenographer', 'Master', 90, 'West Virginia'),
#  (960, 57, 1.76, 74.0, 5, 'Park Keeper', 'PhD', 89, 'South Dakota'),
#  (961, 33, 1.6, 81.0, 2, 'Press Officer', 'Bachelor', 71, 'South Dakota'),
#  (962, 24, 1.92, 59.0, 3, 'Turkey Farmer', 'Bachelor', 84, 'South Dakota'),
#  (963, 46, 1.8, 88.0, 2, 'Paramedic', 'PhD', 84, 'South Dakota'),
#  (964, 33, 1.71, 69.0, 1, 'Property Manager', 'Master', 88, 'South Dakota'),
#  (965, 43, 1.76, 49.0, 0, 'Psychologist', 'Bachelor', 79, 'Delaware'),
#  (966, 52, 1.55, 70.0, 0, 'Tax Consultant', 'PhD', 71, 'South Dakota'),
#  (967, 26, 1.67, 68.0, 5, 'Transport Controller', 'Master', 81, 'Alaska'),
#  (968, 32, 1.88, 44.0, 4, 'Furnace Man', 'Bachelor', 88, 'Louisiana'),
#  (969, 38, 1.69, 71.0, 0, 'Actuary', 'Master', 83, 'Louisiana'),
#  (970, 67, 1.92, 43.0, 2, 'Stone Sawyer', 'Bachelor', 86, 'Alaska'),
#  (971, 33, 1.88, 85.0, 2, 'Applications Engineer', 'PhD', 74, 'Delaware'),
#  (972, 60, 1.95, 58.0, 1, 'Instructor', 'Master', 81, 'Delaware'),
#  (973, 44, 1.66, 66.0, 5, 'Engineer', 'Master', 74, 'Alaska'),
#  (974, 21, 1.64, 38.0, 4, 'Word Processing Operator', 'PhD', 82, 'Louisiana'),
#  (975, 65, 1.77, 73.0, 2, 'Metal Polisher', 'Bachelor', 70, 'West Virginia'),
#  (976, 53, 1.62, 42.0, 2, 'Plant Attendant', 'PhD', 80, 'South Dakota'),
#  (977, 40, 1.57, 68.0, 5, 'Betting Shop', 'Bachelor', 85, 'West Virginia'),
#  (978, 51, 1.54, 63.0, 1, 'Slater', 'PhD', 75, 'West Virginia'),
#  (979, 44, 1.67, 50.0, 5, 'Tunneller', 'Bachelor', 69, 'Alaska'),
#  (980, 42, 1.57, 90.0, 5, 'Storeman', 'Bachelor', 70, 'Louisiana'),
#  (981, 48, 1.84, 83.0, 3, 'Stud Hand', 'Bachelor', 72, 'Delaware'),
#  (982, 37, 1.93, 77.0, 2, 'Production Planner', 'Master', 87, 'Delaware'),
#  (983, 47, 1.96, 59.0, 2, 'Sports Administrator', 'Master', 66, 'Louisiana'),
#  (984, 44, 1.74, 60.0, 3, 'Steel Erector', 'Bachelor', 78, 'Louisiana'),
#  (985, 51, 1.67, 74.0, 1, 'Tiler', 'Bachelor', 69, 'West Virginia'),
#  (986, 33, 1.86, 44.0, 2, 'Wholesale Newspaper', 'PhD', 73, 'Delaware'),
#  (987, 39, 1.65, 67.0, 3, 'Safety Officer', 'Bachelor', 85, 'South Dakota'),
#  (988, 46, 1.58, 68.0, 3, 'Building Estimator', 'Master', 76, 'South Dakota'),
#  (989, 52, 1.85, 65.0, 3, 'Plastics Consultant', 'PhD', 88, 'Delaware'),
#  (990, 21, 1.83, 42.0, 5, 'Tea Taster', 'Bachelor', 73, 'West Virginia'),
#  (991, 61, 1.78, 90.0, 3, 'Hospital Doctor', 'Master', 84, 'Louisiana'),
#  (992, 20, 1.8, 81.0, 4, 'Purchasing Assistant', 'Master', 67, 'Delaware'),
#  (993, 66, 1.83, 43.0, 1, 'Garage Manager', 'PhD', 83, 'Louisiana'),
#  (994, 31, 1.57, 47.0, 3, 'Trichologist', 'Master', 80, 'Delaware'),
#  (995, 39, 1.79, 50.0, 1, 'Partition Erector', 'Master', 74, 'South Dakota'),
#  (996, 31, 1.97, 65.0, 5, 'Playgroup Leader', 'Bachelor', 71, 'South Dakota'),
#  (997, 65, 1.99, 63.0, 1, 'Nursery Nurse', 'Bachelor', 89, 'West Virginia'),
#  (998, 33, 1.77, 41.0, 0, 'Word Processing Operator', 'Master', 87, 'Louisiana'),
#  (999, 63, 1.64, 39.0, 1, 'Shepherd', 'PhD', 71, 'West Virginia')]

# %%
for record in data:
    print(record)
    
    #same as fetchall()

# %%
engine.execute("SELECT DISTINCT location FROM Demographics").fetchall()
# Out:
# [('South Dakota',),
#  ('Delaware',),
#  ('Louisiana',),
#  ('West Virginia',),
#  ('Alaska',)]

# %%
for location in session.query(Demographics.location).distinct():
    print(location)
# Out:
# ('South Dakota',)
# ('Delaware',)
# ('Louisiana',)
# ('West Virginia',)
# ('Alaska',)
